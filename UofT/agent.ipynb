# %% [markdown]
# # 0. Installing Dependencies & Import Libraries

# %%
# !pip install tensorflow
# !pip install keras
# !pip install gym
# !pip install gymnasium
# !pip install keras-rl2
# !pip install stable-baselines3
# !pip install traci
# Out:
# Requirement already satisfied: tensorflow in c:\users\v5run\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\v5run\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\v5run\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v5run\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Requirement already satisfied: keras in c:\users\v5run\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: absl-py in c:\users\v5run\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\v5run\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\v5run\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\v5run\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\v5run\anaconda3\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\v5run\anaconda3\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in c:\users\v5run\anaconda3\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\v5run\anaconda3\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\v5run\anaconda3\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v5run\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: gym in c:\users\v5run\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\v5run\anaconda3\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\v5run\anaconda3\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\v5run\anaconda3\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: gymnasium in c:\users\v5run\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: keras-rl2 in c:\users\v5run\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in c:\users\v5run\anaconda3\lib\site-packages (from keras-rl2) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow->keras-rl2) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.4.0)
# Requirement already satisfied: packaging in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\v5run\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.44.0)
# Requirement already satisfied: rich in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (13.7.1)
# Requirement already satisfied: namex in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.0.8)
# Requirement already satisfied: optree in c:\users\v5run\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\v5run\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\v5run\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\v5run\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\v5run\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\v5run\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.1.0)
# Requirement already satisfied: stable-baselines3 in c:\users\v5run\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\v5run\anaconda3\lib\site-packages (from stable-baselines3) (3.9.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\v5run\anaconda3\lib\site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: networkx in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\v5run\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\v5run\anaconda3\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\v5run\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\v5run\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\v5run\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\v5run\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\v5run\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (2.1.3)
# Requirement already satisfied: traci in c:\users\v5run\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: sumolib>=1.21.0 in c:\users\v5run\anaconda3\lib\site-packages (from traci) (1.21.0)

# %%
import numpy as np
import random
import gymnasium
import sumolib
import time
import traci

# %% [markdown]
# # 1. OpenAI Gymnasium Environment

# %%
class SumoEnv(gymnasium.Env):
  def __init__(self, use_gui=False, use_random=False, use_actions=True):
    super().__init__() # Initializes the parent class

    self.traffic_light_id = "cluster_21436517_21436518_391169149"

    # Check if TraCI is already loaded; if so, close it
    if traci.isLoaded():
      traci.close()

    # Define the Discrete action space with gymnasium.spaces.Discrete(n)
    # choices are up & down = green, or l & r = green
    self.action_space = gymnasium.spaces.Discrete(3)

    # Define the Box observation space with gymnasium.spaces.Box()
    # Note the structure of the Box parameters requires NumPy arrays!
    
    max_cars = 20 # CHANGE FOR ACTUAL MAX. NUMBER OF CARS
    self.max_cars = max_cars
    
    self.car_spawn_rate = 1 # cars spawn at 30% chance

    # np array structure: [traffic_light_phase][positions][speeds], dtype=np.float32
    self.observation_space = gymnasium.spaces.Box(
      low=np.array([0] + [-np.inf] * (2 * max_cars) + [0] * max_cars),
      high=np.array([7] + [np.inf] * (2 * max_cars) + [np.inf] * max_cars),
      dtype=np.float32
    )
    
    # Upon each render of the SumoEnv Class, we should start the simulation
    # Implement the sumo_binary, sumo_config, and traci.start from test_demo.py
    self.use_gui = use_gui
    if use_gui:
      sumo_binary = sumolib.checkBinary('sumo-gui')
    else:
      sumo_binary = sumolib.checkBinary('sumo')

    # use the proper .sumocfg file depending on if want predefined or random cars
    self.use_random = use_random
    if use_random:
      sumo_config = "./car_only_network/uoft.sumocfg"

    else:
      sumo_config = "./car_only_network/uoft.sumocfg"


    # used to track number of deployed cars
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # store these variables for use later
    self.sumo_binary = sumo_binary
    self.sumo_config = sumo_config

    # Start the simulation
    self.started = False

    # Track cumulative metrics
    self.vehicle_wait_log = {}
    self.total_congestion_log = []
    self.total_speed_log = []

    # use actions argument: False = use the timer based system instead (for comparing between agent and real-life)
    self.use_actions = use_actions

    # Define consistent pause time for sumo-gui visualization
    self.pause_time = 0.1

  def step(self, action):
    # On first step, start the traci sim
    if not self.started:
      traci.start([self.sumo_binary, "--start", "-c", self.sumo_config])
      self.started = True
      traffic_light_id = traci.trafficlight.getIDList()[0]
      traci.trafficlight.setPhase(traffic_light_id, 0)
      if self.use_actions:
        traci.trafficlight.setPhaseDuration(traffic_light_id, 99999)  # Hold this phase indefinitely
    
    # Perform the action
    if self.use_actions:
      self.perform_action(action)
    
    # Spawn in a car if suits the spawn rate on step
    if self.use_random:
      if (random.random() < self.car_spawn_rate) and (self.deployed_counter < self.max_cars):
        self.spawn_random_car(self.deployed_counter)
        self.deployed_counter += 1
  

    # Advance the simulation by one step
    traci.simulationStep()
    if self.use_gui: # pause in between steps to slow down if in 'simulation mode'
      time.sleep(self.pause_time) 
    print("Step: " + str(traci.simulation.getTime()))
    # Get the new state
    observation = self.get_state()

    # Calculate the reward
    reward = self.calculate_reward()

    # Determine if simulation is done
    done = self.is_done()

    # Set placeholder for info -> returns the tracked cumulative metrics IF done
    info = {
      "vehicle_wait_log": self.vehicle_wait_log if done else None,
      "total_congestion_avg": (sum(self.total_congestion_log) / len(self.total_congestion_log)) if done and self.total_congestion_log else None,
      "total_speed_avg": (sum(self.total_speed_log) / len(self.total_speed_log)) if done and self.total_speed_log else None
    }

    # Set placeholder for truncated
    truncated = False

    # set 'observation' to a numpy array
    observation = np.array(observation, dtype=np.float32)

    # Return step information (MUST follow this order of variables!!!)
    return observation, reward, done, truncated, info

  def render(self):
    # render needs to exist in the Gymnasium env, as it is an essential aspect
    # however we might not need to put anything inside it, hence 'pass'
    # this depends on if the command -> traci.simulationStep() exists somewhere else in the Class
    pass

  def reset(self, seed=None, options=None):

    # resets the gymnasium.Env parent class
    super().reset(seed=seed)

    # close the simulation (reset)
    if not self.use_gui: # traci.load() doesn't work for sumo-gui - i.e. can only run once
      traci.load(["-c", self.sumo_config])

    # reset counter variables
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # convert 'observation' to a NumPy array
    observation = np.array(self.get_state(), dtype=np.float32)

    # return 'observation' and 'info' --> MUST be in this form
    return observation, {}

  def get_state(self):
    # Get the traffic light phase
    traffic_light_ids = traci.trafficlight.getIDList()
    traffic_light_phase = traci.trafficlight.getPhase(traffic_light_ids[0]) # only 1 in this network

    # Get vehicle IDs and limit to max_cars
    vehicle_ids = traci.vehicle.getIDList()

    # Collect positions and speeds, padding if fewer than max_cars
    positions = []
    speeds = []
    for v_id in vehicle_ids:
      position = traci.vehicle.getPosition(v_id)  # Returns (x, y) tuple
      speed = traci.vehicle.getSpeed(v_id)
      positions.extend(position)  # Add x, y to positions list
      speeds.append(speed)

    # Pad positions and speeds if there are fewer than max_cars vehicles
    if len(vehicle_ids) < self.max_cars:
      missing_cars = self.max_cars - len(vehicle_ids)
      positions.extend([0.0, 0.0] * missing_cars)
      speeds.extend([0.0] * missing_cars)

    # Create the state as a numpy array
    obs = np.array([traffic_light_phase] + positions + speeds, dtype=np.float32)
    return obs

  def perform_action(self, action):
    
    light_id = self.traffic_light_id
    current_phase = traci.trafficlight.getPhase(light_id)

    """
    Phases: 
      (0) E & W = red, N & S = green
      (1) E & W = red, N & S = yellow
      (2) E & W = red, N & S left turns green
      (3) E & W = red, N & S left turns yellow
      (4) all red
      (5) E & W = green, N & S = red
      (6) E & W = yellow, N & S = red 
      (7) all red
      
      Define action 0 as switching green to E & W; thus turning N & S left turns yellow (9), then red (10), then E&W green (0)
      Define action 1 as switching green to N left turn/U-turn for streetcars; thus make E&W yellow (1) then red (2) then make N left turns green (3)
      Define action 2 as switching green to N&S both; thus make turn yellow (4) then red (5) then make N&S green (6)
      Define action 3 as switching green to S left turn; thus make straights yellow (7), then make straights red (8)

      new:
      define action 0 as switching N&S to green. first EW is yellow, then red, then N-S is green
      define action 1 as only N&S left turns, first N-S is yellow, then only left turns 
      define action 2 as E&W green, left turns turn yellow, then all red, then E-W green
    """

    if action == 0 and current_phase != 0:
      traci.trafficlight.setPhase(light_id, 6)  # transition to yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)  # set yellow duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 7)  # all red
      traci.trafficlight.setPhaseDuration(light_id, 1)  # set red duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 0)  # set N-S green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
      self.skip_steps(5) # ensure light is green for at least 3 seconds

    elif action == 1 and current_phase != 2:
      traci.trafficlight.setPhase(light_id, 1)  # transition to yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)  # set yellow duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 2)  # N-S left turns
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
      self.skip_steps(5) # ensure light is green for at least 3 seconds

    elif action == 2 and current_phase != 6:
      traci.trafficlight.setPhase(light_id, 3)  # transition to yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)  # set yellow duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 4)  # all red
      traci.trafficlight.setPhaseDuration(light_id, 1)  # set red duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 5)  # set N-S green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
      self.skip_steps(5) # ensure light is green for at least 3 seconds


  def calculate_reward(self):
    # REWARD FUNCTION: Calculate the reward (should be negative if in a poor state i.e. high congestion)
    lane_ids = traci.lane.getIDList()
    vehicle_ids = traci.vehicle.getIDList()
    try:
      congestion = self.calculate_congestion(vehicle_ids)
      wait_time = self.calculate_avg_wait_time(lane_ids)
      stops = self.calculate_total_stops(lane_ids)
      avg_speed = self.calculate_avg_speed(vehicle_ids)# -> would be maximize so don't multiply by -1
      reward = -1*(1.5*congestion + 1.5*wait_time + stops) + 0.75*avg_speed # minimize all terms
    except:
      reward = 0

    return reward

  def skip_steps(self, x):
    for _ in range(x): 
      traci.simulationStep()
      if self.use_gui:
        time.sleep(self.pause_time)

  def is_done(self):
    max_time = 1000  # Example maximum simulation time
    return (traci.simulation.getTime() >= max_time or len(traci.vehicle.getIDList()) == 0) and self.deployed_counter != 0


  # METRICS:
  def calculate_congestion(self, vehicle_ids):
    congestion = 0
    current_time = traci.simulation.getTime()  # Get the current simulation time
    
    for vehicle_id in vehicle_ids:
      departure_time = traci.vehicle.getDeparture(vehicle_id)  # Get each vehicle's departure time
      speed = traci.vehicle.getSpeed(vehicle_id)  # Get the vehicle's current speed
      
      # Check if the vehicle is stopped and not just starting/departing
      if speed == 0 and current_time not in range(int(departure_time) - 1, int(departure_time) + 2):
          congestion += 1  # Increment congestion counter for stopped vehicles
  
    # update congestion log
    self.total_congestion_log.append(congestion)

    return congestion


  def calculate_avg_wait_time(self, lane_ids):
    wait_times = []
    
    # total wait time of cars in all lanes
    for lane_id in lane_ids:
      # total wait time of all cars in one lane
      for vehicle_id in traci.lane.getLastStepVehicleIDs(lane_id):
          wait_time = traci.vehicle.getWaitingTime(vehicle_id)

          # update the wait log
          if vehicle_id in self.vehicle_wait_log:
            self.vehicle_wait_log[vehicle_id] = max(self.vehicle_wait_log[vehicle_id], wait_time) # only want the greatest average wait time for each vehicle
          else:
            self.vehicle_wait_log[vehicle_id] = wait_time

          wait_times.append(wait_time)
  
    avg_wait_time = sum(wait_times)/len(wait_times) if wait_times else 0
    
    return avg_wait_time

  def calculate_total_stops(self, lane_ids):
    total_stops = 0
    for lane_id in lane_ids:
      stops_in_lane = traci.lane.getLastStepHaltingNumber(lane_id)
      total_stops += stops_in_lane

    return total_stops
    
  def calculate_avg_speed(self, vehicle_ids):
    total_speed = sum(traci.vehicle.getSpeed(v_id) for v_id in vehicle_ids)
    avg_speed = total_speed / len(vehicle_ids) if vehicle_ids else 0

    # update total speed log
    self.total_speed_log.append(avg_speed)

    return avg_speed

  def spawn_random_car(self, step_counter):
    """
    Spawns a random car with a unique ID and assigns it a random route.
    edge_mapping represents the available routes that any car can take; start_edge:end_edge
    """
    edge_mapping = {
        "33002810#0":"33002812#0", 
        "33002810#0":"22891215#0", 
        "33002810#0":"-1183480610#4", 
        "33002810#0":"22891216#0", # south moving right, straight, left

        "-33002812#2":"22891215#0", 
        "-33002812#2":"-1183480610#4", 
        "-33002812#2":"22891216#0",
        "-33002812#2":"33002812#0", # east

        "33002813#0":"-1183480610#4", 
        "33002813#0":"22891216#0", 
        "33002813#0":"33002812#0",
        "33002813#0":"22891215#0", # north

        "1183480610#0":"22891216#0", 
        "1183480610#0":"33002812#0", 
        "1183480610#0":"22891215#0",
        "1183480610#0":"-1183480610#4" # west
    }
    
    vehicle_id = f"rand_car_{step_counter}"

    # edges = traci.edge.getIDList()
    # start_edges = []
    # for edge in edges:
    #     if not edge.startswith('-') and not edge.startswith(':') and edge in edge_mapping:
    #         start_edges.append(edge)
    
    start_edge = random.choice(list(edge_mapping.keys()))
    end_edge = edge_mapping[start_edge]

    route_id = f"route_{vehicle_id}"

    try:
        traci.route.add(routeID=route_id, edges=[start_edge, end_edge])

        # Add the vehicle to the simulation
        traci.vehicle.add(vehID=vehicle_id, routeID=route_id)

        print(f"Deployed random vehicle {vehicle_id} from {start_edge} to {end_edge}")

        # Set a random speed for the vehicle
        traci.vehicle.setSpeed(vehicle_id, random.uniform(5, 15))

    except traci.TraCIException as e:
        print(f"Failed to add vehicle {vehicle_id} on route from {start_edge} to {end_edge}: {e}")

# %% [markdown]
# ### Simulation with SUMO-GUI

# %%
'''
    The purpose of this is just to visualize our results!
    Explanation of SumoEnv parameters:
        use_gui = True runs with sumo gui
        use_gui = False runs sumo (all same functionality just doesn't render anything)
        use_random = False tells the env NOT to deploy random vehicles
        use_random = True tells the env to deploy random vehicles
        use_actions = False tells the env that we are running with random actions (note can ONLY use False here since we are using env.action_space.sample() later)
        use_actions = True tell the env that we are running with actions chosen by the agent (will NOT work yet since we don't have an agent!)
'''

env = SumoEnv(use_gui=True, use_random=True, use_actions=True) # use_gui=False sets sumo_binary to 'sumo' instead of 'sumo-gui'

episodes = 100 # note can only be run ONCE with sumo-gui!
score_log = []
wait_log = []

congestion_log = []
speed_log = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    score = 0
    info = {}

    while not done:
        env.render()
        action = env.action_space.sample()
        state, reward, done, truncated, info = env.step(action)
        score += reward

    state, _ = env.reset()
    score_log.append(score)

    # Extract wait time metrics
    wait_times = info.get("vehicle_wait_log", {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars if num_cars > 0 else 0
    wait_log.append(episode_mean_wait)

    # Extract congestion and speed metrics
    if info.get("total_congestion_avg") is not None:
        congestion_log.append(info["total_congestion_avg"])
    if info.get("total_speed_avg") is not None:
        speed_log.append(info["total_speed_avg"])

traci.close()

# Compute and print final metrics
mean_sample_score = np.mean(score_log)
mean_wait_time = np.mean(wait_log)
mean_congestion = np.mean(congestion_log) if congestion_log else None
mean_speed = np.mean(speed_log) if speed_log else None

print(f"Mean Score over {episodes} episodes: {mean_sample_score}")
print(f"Mean wait time over {episodes} episodes: {mean_wait_time}")
print(f"Mean congestion over {episodes} episodes: {mean_congestion}")
print(f"Mean speed over {episodes} episodes: {mean_speed}")
# Out:
# Deployed random vehicle rand_car_0 from 33002813#0 to 22891215#0
# Step: 9.0
# Deployed random vehicle rand_car_1 from 1183480610#0 to -1183480610#4
# Step: 21.0
# Deployed random vehicle rand_car_2 from 1183480610#0 to -1183480610#4
# Step: 30.0
# Deployed random vehicle rand_car_3 from 33002813#0 to 22891215#0
# Step: 42.0
# Deployed random vehicle rand_car_4 from -33002812#2 to 33002812#0
# Step: 51.0
# Deployed random vehicle rand_car_5 from -33002812#2 to 33002812#0
# Step: 63.0
# Deployed random vehicle rand_car_6 from 33002813#0 to 22891215#0
# Step: 75.0
# Deployed random vehicle rand_car_7 from 1183480610#0 to -1183480610#4
# Step: 84.0
# Deployed random vehicle rand_car_8 from 33002813#0 to 22891215#0
# Step: 85.0
# Deployed random vehicle rand_car_9 from 33002813#0 to 22891215#0
# Step: 97.0
# Deployed random vehicle rand_car_10 from 1183480610#0 to -1183480610#4
# Step: 109.0
# Deployed random vehicle rand_car_11 from 33002813#0 to 22891215#0
# Step: 121.0
# Deployed random vehicle rand_car_12 from 33002810#0 to 22891216#0
# Step: 130.0
# Deployed random vehicle rand_car_13 from 33002810#0 to 22891216#0
# Step: 131.0
# Deployed random vehicle rand_car_14 from -33002812#2 to 33002812#0
# Step: 132.0
# Deployed random vehicle rand_car_15 from 33002813#0 to 22891215#0
# Step: 144.0
# Deployed random vehicle rand_car_16 from 1183480610#0 to -1183480610#4
# Step: 145.0
# Deployed random vehicle rand_car_17 from 33002810#0 to 22891216#0
# Step: 154.0
# Deployed random vehicle rand_car_18 from -33002812#2 to 33002812#0
# Step: 166.0
# Deployed random vehicle rand_car_19 from 1183480610#0 to -1183480610#4
# Step: 175.0
# Step: 187.0
# Step: 188.0
# Step: 197.0
# Step: 198.0
# Step: 210.0
# Step: 211.0
# Step: 220.0
# Step: 221.0
# Step: 222.0
# Step: 234.0
# Step: 246.0
# Step: 247.0
# Step: 256.0
# Step: 268.0
# Step: 277.0
# Step: 289.0
# Step: 301.0
# Step: 302.0
# Step: 311.0
# Step: 323.0
# Step: 335.0
# Step: 347.0
# Step: 356.0
# Step: 357.0
# Step: 358.0
# Step: 359.0
# Step: 371.0
# Step: 380.0
# Step: 392.0
# Step: 404.0
# Step: 413.0
# Step: 414.0
# Step: 426.0
# Step: 435.0
# Step: 447.0
# Step: 459.0
# Step: 468.0
# Step: 469.0
# Step: 470.0
# Step: 482.0
# Step: 483.0
# Step: 495.0
# Step: 507.0
# Step: 519.0
# Step: 520.0
# Step: 532.0
# Step: 541.0
# Step: 542.0
# Step: 554.0
# Step: 563.0
# Step: 575.0
# Step: 587.0
# Step: 599.0
# Step: 608.0
# Step: 609.0
# Step: 610.0
# Step: 622.0
# Step: 634.0
# Step: 643.0
# Step: 655.0
# Step: 667.0
# Step: 676.0
# Step: 688.0
# Step: 697.0
# Step: 709.0
# Step: 721.0
# Step: 733.0
# Step: 742.0
# Step: 754.0
# Step: 755.0
# Step: 767.0
# Step: 779.0
# Step: 788.0
# Step: 800.0
# Step: 812.0
# Step: 813.0
# Step: 825.0
# Step: 837.0
# Step: 846.0
# Step: 858.0
# Step: 870.0
# Step: 882.0
# Step: 883.0
# Step: 892.0
# Step: 904.0
# Step: 913.0
# Step: 925.0
# Step: 934.0
# Step: 946.0
# Step: 955.0
# Step: 956.0
# Step: 968.0
# Step: 980.0
# Step: 992.0
# Step: 1004.0
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[12], line 30
#      28     env.render()
#      29     action = env.action_space.sample()
# ---> 30     state, reward, done, truncated, info = env.step(action)
#      31     score += reward
#      33 state, _ = env.reset()
#
# Cell In[11], line 83, in SumoEnv.step(self, action)
#      81 # Perform the action
#      82 if self.use_actions:
# ---> 83   self.perform_action(action)
#      85 # Spawn in a car if suits the spawn rate on step
#      86 if self.use_random:
#
# Cell In[11], line 225, in SumoEnv.perform_action(self, action)
#     223 traci.trafficlight.setPhase(light_id, 3)  # transition to yellow
#     224 traci.trafficlight.setPhaseDuration(light_id, 4)  # set yellow duration
# --> 225 self.skip_steps(3)
#     226 traci.trafficlight.setPhase(light_id, 4)  # all red
#     227 traci.trafficlight.setPhaseDuration(light_id, 1)  # set red duration
#
# Cell In[11], line 251, in SumoEnv.skip_steps(self, x)
#     249 def skip_steps(self, x):
#     250   for _ in range(x):
# --> 251     traci.simulationStep()
#     252     if self.use_gui:
#     253       time.sleep(self.pause_time)
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:198, in simulationStep(step)
#     192 def simulationStep(step=0):
#     193     """simulationStep(float) -> None
#     194     Make a simulation step and simulate up to the given second in sim time.
#     195     If the given value is 0 or absent, exactly one step is performed.
#     196     Values smaller than or equal to the current sim time result in no action.
#     197     """
# --> 198     connection.check().simulationStep(step)
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:369, in Connection.simulationStep(self, step)
#     367 if type(step) is int and step >= 1000:
#     368     warnings.warn("API change now handles step as floating point seconds", stacklevel=2)
# --> 369 result = self._sendCmd(tc.CMD_SIMSTEP, None, None, "D", step)
#     370 for subscriptionResults in self._subscriptionMapping.values():
#     371     subscriptionResults.reset()
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:232, in Connection._sendCmd(self, cmdID, varID, objID, format, *values)
#     230     self._string += struct.pack("!i", len(objID)) + objID
#     231 self._string += packed
# --> 232 return self._sendExact()
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\connection.py:137, in Connection._sendExact(self)
#     135     self._socket.close()
#     136     self._socket = None
# --> 137     raise FatalTraCIError("Connection closed by SUMO.")
#     138 for command in self._queue:
#     139     prefix = result.read("!BBB")
#
# FatalTraCIError: Connection closed by SUMO.

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# CREATE NEW VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
#check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# TRAIN AGENT
model = PPO("MlpPolicy", env, verbose=1)
# can change number of timesteps, however at least 10000 to make a semi-decent one
model.learn(total_timesteps=10000) # takes ~30 mins

# %%
# SAVE THE MODEL
model.save("mcmaster-model") # creates .zip in current working directory

# %%
loaded_model = PPO.load("mcmaster-model")

# %%
# CREATE VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
#check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODES
num_test_episodes = 100
all_scores = []
wait_log = []
# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0
    info = {}
    while not done:
        action, _states = loaded_model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)

    print(info)
    wait_times = info[0].get('vehicle_wait_log', {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars
    wait_log.append(episode_mean_wait)

traci.close()
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")
print(f"Mean wait time over {num_test_episodes} episodes: {np.mean(wait_log)}")
