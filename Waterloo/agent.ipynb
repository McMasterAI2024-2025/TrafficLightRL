# %% [markdown]
# # 0. Installing Dependencies & Import Libraries

# %%
# !pip install tensorflow
# !pip install keras
# !pip install gym
# !pip install gymnasium
# !pip install keras-rl2
# !pip install stable-baselines3
# !pip install traci
# Out:
# Requirement already satisfied: tensorflow in c:\users\clara\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\clara\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\clara\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clara\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Requirement already satisfied: keras in c:\users\clara\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: absl-py in c:\users\clara\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\clara\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\clara\anaconda3\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\clara\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\clara\anaconda3\lib\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\clara\anaconda3\lib\site-packages (from keras) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\clara\anaconda3\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\clara\anaconda3\lib\site-packages (from keras) (23.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\clara\anaconda3\lib\site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clara\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: gym in c:\users\clara\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\clara\anaconda3\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\clara\anaconda3\lib\site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\clara\anaconda3\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: gymnasium in c:\users\clara\anaconda3\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: keras-rl2 in c:\users\clara\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: tensorflow in c:\users\clara\anaconda3\lib\site-packages (from keras-rl2) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow->keras-rl2) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.4.0)
# Requirement already satisfied: packaging in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\clara\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.41.2)
# Requirement already satisfied: rich in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (13.3.5)
# Requirement already satisfied: namex in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.0.8)
# Requirement already satisfied: optree in c:\users\clara\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\clara\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\clara\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\clara\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\clara\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\clara\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow->keras-rl2) (0.1.0)
# Requirement already satisfied: stable-baselines3 in c:\users\clara\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (2.5.1)
# Requirement already satisfied: cloudpickle in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\clara\anaconda3\lib\site-packages (from stable-baselines3) (3.8.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\clara\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\clara\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: networkx in c:\users\clara\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3) (3.1)
# Requirement already satisfied: jinja2 in c:\users\clara\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\clara\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3) (2023.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\clara\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\clara\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\clara\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clara\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\clara\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\clara\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\clara\anaconda3\lib\site-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.3)
# Requirement already satisfied: traci in c:\users\clara\anaconda3\lib\site-packages (1.21.0)
# Requirement already satisfied: sumolib>=1.21.0 in c:\users\clara\anaconda3\lib\site-packages (from traci) (1.21.0)

# %%
import numpy as np
import random
import gymnasium
import sumolib
import time
import traci

# %% [markdown]
# # 1. OpenAI Gymnasium Environment

# %%
class SumoEnv(gymnasium.Env):
  def __init__(self, use_gui=True, use_random=False, use_actions=True, spawn_rate=0.5):
    super().__init__() # Initializes the parent class

    # Check if TraCI is already loaded; if so, close it
    if traci.isLoaded():
      traci.close()

    # Define the Discrete action space with gymnasium.spaces.Discrete(n)
    # choices are up & down = green, or l & r = green
    self.action_space = gymnasium.spaces.Discrete(4)

    # Define the Box observation space with gymnasium.spaces.Box()
    # Note the structure of the Box parameters requires NumPy arrays!
    self.lanes = {
      # Edge 1 (East incoming)
      "466414380#0_0": {"type": [0, 1, 1], "phases": [0]},  # Right-turn/straight lane
      "466414380#0_1": {"type": [0, 1, 0], "phases": [0]},  # Straight lane
      "466414380#0_2": {"type": [0, 1, 0], "phases": [2]},  # Left-turn/U-turn lane

      # Edge 2 (West incoming)
      "466414379#0_0": {"type": [0, 1, 1], "phases": [0]},  # Right-turn/straight lane
      "466414379#0_1": {"type": [0, 1, 0], "phases": [0]},  # Straight lane
      "466414379#0_2": {"type": [1, 0, 0], "phases": [2]},  # Left-turn/U-turn lane

      # Edge 3 (South incoming)
      "25634438#0_2": {"type": [1, 0, 0], "phases": [6]},  # Left-turn/U-turn lane
      "25634438#0_1": {"type": [0, 1, 0], "phases": [4]},  # Straight lane
      "25634438#0_0": {"type": [0, 1, 1], "phases": [4]},  # Right-turn/Straight lane

      # Edge 4 (North incoming)
      "466414089#1_2": {"type": [1, 0, 0], "phases": [6]},  # Left-turn/U-turn lane
      "466414089#1_1": {"type": [0, 1, 0], "phases": [4]},  # Straight lane
      "466414089#1_0": {"type": [0, 1, 1], "phases": [4]}  # Right-turn/Straight lane
    }

    self.last_phase_change_time = {
      0: 0,
      2: 0, 
      4: 0,
      6: 0
    }
    
    self.vehicle_emissions = {}
    self.max_wait_time = 1000
    num_lanes=12
    num_metrics_per_lane = 5
    num_lane_type_features=3 # [left, straight, right] "one-hot" encoding
    observation_size = 2 + num_lanes * (num_metrics_per_lane + num_lane_type_features)

    max_cars = 100 # CHANGE FOR ACTUAL MAX. NUMBER OF CARS
    self.max_cars = max_cars
    
    self.car_spawn_rate = spawn_rate # cars spawn at 30% chance

    # np array structure: [traffic_light_phase][positions][speeds], dtype=np.float32
    self.observation_space = gymnasium.spaces.Box(
      low=np.array([0.0] * observation_size),
      high=np.array([1.0] * observation_size), # MUST CHANGE THE TRAFFIC LIGHT PHASE VALUE TO YOUR RESPECTIVE MAX!
      dtype=np.float32
    )
    
    # Upon each render of the SumoEnv Class, we should start the simulation
    # Implement the sumo_binary, sumo_config, and traci.start from test_demo.py
    self.use_gui = use_gui
    if use_gui:
      sumo_binary = sumolib.checkBinary('sumo-gui')
    else:
      sumo_binary = sumolib.checkBinary('sumo')

    # use the proper .sumocfg file depending on if want predefined or random cars
    self.use_random = use_random
    if use_random:
      sumo_config = "./Network/waterloo.sumocfg"
    else:
      sumo_config = "./Network/waterloo.sumocfg"

    # used to track number of deployed cars
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # store these variables for use later
    self.sumo_binary = sumo_binary
    self.sumo_config = sumo_config

    # Start the simulation
    self.started = False

    # Track cumulative metrics
    self.vehicle_wait_log = {}
    self.total_congestion_log = []
    self.total_speed_log = []

    # use actions argument: False = use the timer based system instead (for comparing between agent and real-life)
    self.use_actions = use_actions

    # Define consistent pause time for sumo-gui visualization
    self.pause_time = 0.25

  def step(self, action):
    # On first step, start the traci sim
    if not self.started:
      traci.start([self.sumo_binary, "--start", "-c", self.sumo_config])
      self.started = True
      
      traffic_light_id = traci.trafficlight.getIDList()[2]

      #traci.trafficlight.setProgram(traffic_light_id, "0") 
      traci.trafficlight.setPhase(traffic_light_id, 0)
      if self.use_actions:
        traci.trafficlight.setPhaseDuration(traffic_light_id, 99999)  # Hold this phase indefinitely
    
    # Perform the action
    if self.use_actions:
      self.perform_action(action)
    
    # Spawn in a car if suits the spawn rate on step
    if self.use_random:
      if (random.random() < self.car_spawn_rate) and (self.deployed_counter < self.max_cars):
        self.spawn_random_car(self.deployed_counter)
        self.deployed_counter += 1

    # get the most updated vehicle emission for each vehicle in the simulation
    for vehicle_id in traci.vehicle.getIDList():
      if vehicle_id not in self.vehicle_emissions:
        self.vehicle_emissions[vehicle_id] = 0
      self.vehicle_emissions[vehicle_id] = traci.vehicle.getCO2Emission(vehicle_id)
  

    # Advance the simulation by one step
    traci.simulationStep()
    if self.use_gui: # pause in between steps to slow down if in 'simulation mode'
      time.sleep(self.pause_time) 
    #print("Step: " + str(traci.simulation.getTime()))
    # Get the new state
    observation = self.get_state()

    # Calculate the reward
    reward = self.calculate_reward()

    # Determine if simulation is done
    done = self.is_done()

    # Set placeholder for info -> returns the tracked cumulative metrics IF done
    info = {
      "vehicle_wait_log": self.vehicle_wait_log if done else None,
      "total_congestion_avg": (sum(self.total_congestion_log) / len(self.total_congestion_log)) if done and self.total_congestion_log else None,
      "total_speed_avg": (sum(self.total_speed_log) / len(self.total_speed_log)) if done and self.total_speed_log else None,
      "emissions": self.calculate_mean_emission()
    }

    # Set placeholder for truncated
    truncated = False

    # set 'observation' to a numpy array
    observation = np.array(observation, dtype=np.float32)

    # Return step information (MUST follow this order of variables!!!)
    return observation, reward, done, truncated, info

  def render(self):
    # render needs to exist in the Gymnasium env, as it is an essential aspect
    # however we might not need to put anything inside it, hence 'pass'
    # this depends on if the command -> traci.simulationStep() exists somewhere else in the Class
    pass

  def reset(self, seed=None, options=None):
    # resets the gymnasium.Env parent class
    super().reset(seed=seed)

    # close the simulation (reset)
    if not self.use_gui:  # traci.load() doesn't work for sumo-gui - i.e. can only run once
        traci.load(["-c", self.sumo_config])

    # reset counter variables
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # convert 'observation' to a NumPy array
    observation = np.array(self.get_state(), dtype=np.float32)

    self.last_phase_change_time = { # note: each of the keys correspond to one of my end state phases
      0: 0,
      2: 0, 
      4: 0,
      6: 0
    }

    self.vehicle_emissions = {}
    self.vehicle_wait_log = {}
    self.total_congestion_log = []
    self.total_speed_log = []

    # return 'observation' and 'info' --> MUST be in this form
    return observation, {}


  def get_state(self):
    # Define a speed threshold for "stopped" vehicles
    speed_threshold = 0.1  # Vehicles with speed < 0.1 m/s are considered stopped

    state = []

    # 1. Traffic light phase (normalized to [0, 1])
    traffic_light_phase = traci.trafficlight.getPhase(traci.trafficlight.getIDList()[0])
    state.append(traffic_light_phase / 9.0)  # Normalize phase to [0, 1]
    for phase_change_time in self.last_phase_change_time:
      if phase_change_time == traffic_light_phase:
        self.last_phase_change_time[phase_change_time] = 0
      else:
        self.last_phase_change_time[phase_change_time] += 1

    # 2. Time since last phase change (normalized to [0, 1])
    current_time = traci.simulation.getTime()
    time_since_last_change = current_time - min(self.last_phase_change_time.values())
    state.append(time_since_last_change / self.max_wait_time)  # Normalize using max_wait_time

    # 3. Per-lane metrics (only for lanes directly connected to the intersection)
    for lane_id, lane_info in self.lanes.items():
        vehicle_ids = traci.lane.getLastStepVehicleIDs(lane_id)

        # Number of vehicles (normalized to [0, 1])
        num_vehicles = len(vehicle_ids)
        state.append(num_vehicles / self.max_cars)

        # Queue length (number of vehicles with speed < threshold, normalized to [0, 1])
        queue_length = sum(1 for v_id in vehicle_ids if traci.vehicle.getSpeed(v_id) < speed_threshold)
        state.append(queue_length / self.max_cars)

        # Total wait time (normalized to [0, 1])
        total_wait_time = sum(traci.vehicle.getWaitingTime(v_id) for v_id in vehicle_ids)
        state.append(total_wait_time / self.max_wait_time)  # Normalize using max_wait_time

        # Average speed (normalized to [0, 1])
        avg_speed = np.mean([traci.vehicle.getSpeed(v_id) for v_id in vehicle_ids]) if vehicle_ids else 0
        state.append(avg_speed / traci.lane.getMaxSpeed(lane_id))  # Normalize to [0, 1]

        # Time since last visited  
        minn = float("inf")
        for phase in lane_info["phases"]:
          if self.last_phase_change_time[phase] < minn:
            minn = self.last_phase_change_time[phase]
        state.append(minn / float(max(self.last_phase_change_time.values())))

        # Lane type (one-hot encoded)
        lane_type = lane_info["type"]
        state.extend(lane_type)

    return np.array(state, dtype=np.float32)

  def perform_action(self, action):

    light_id = traci.trafficlight.getIDList()[2]
    current_phase = traci.trafficlight.getPhase(light_id)
   
    """
    Phases: 
      (0) E & W = green, N & S = red
      (1) E & W = yellow, N & S = red
      (2) E & W left turn/U-turn = green, N & S = red
      (3) E & W left turn/U-turn = yellow, N & S = red
      (4) E & W = red, N & S = green
      (5) E & W = red, N & S = yellow
      (6) E & W = red, N & S left turn/U-turn = green 
      (7) E & W = red, N & S left turn/U-turn = yellow 

      Define action 0 as switching green to E & W; thus turning N & S red
      Define action 1 as switching green to E & W left turn/U-turn; thus turning all straight and right turns red
      Define action 2 as switching green to N & S; thus turning E & W red
      Define action 3 as switching green to N & S left turn/U-turn; thus turning all straight and right turns red

      Also, no actions can be performed during yellow light!
    """
    if action == 0 and current_phase != 0:
      traci.trafficlight.setPhase(light_id, 1)  # transition to yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)  # set yellow duration
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 0)  # set E-W green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
      self.skip_steps(5) # ensure light is green for at least 3 seconds

    elif action == 1 and current_phase != 2:
      traci.trafficlight.setPhase(light_id, 1)  # E-W yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)
      self.skip_steps(3)
      traci.trafficlight.setPhase(light_id, 2)  # set E-W left turn/U-turn green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
      self.skip_steps(5)

    elif action == 2 and current_phase != 4:
      traci.trafficlight.setPhase(light_id, 4)  # Set N-S green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold green indefinitely
      self.skip_steps(5)  # Ensure light stays green for at least 3 seconds
      
      traci.trafficlight.setPhase(light_id, 5)  # Transition to N-S yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)
      self.skip_steps(3)

    elif action == 3 and current_phase != 6:
      traci.trafficlight.setPhase(light_id, 6)  # Set N-S left turn/U-turn green
      traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold green indefinitely
      self.skip_steps(5)  # Ensure light stays green for at least 3 seconds
      
      traci.trafficlight.setPhase(light_id, 7)  # Transition to N-S left turn yellow
      traci.trafficlight.setPhaseDuration(light_id, 4)
      self.skip_steps(3)

  def calculate_reward(self):
    # REWARD FUNCTION: Calculate the reward (should be negative if in a poor state i.e. high congestion)
    lane_ids = traci.lane.getIDList()
    vehicle_ids = traci.vehicle.getIDList()
    try:
      congestion = self.calculate_congestion(vehicle_ids)
      wait_time = self.calculate_avg_wait_time(lane_ids)
      stops = self.calculate_total_stops(lane_ids)
      avg_speed = self.calculate_avg_speed(vehicle_ids)# -> would be maximize so don't multiply by -1
      reward = -1*(1.5*congestion + 1.5*wait_time + stops) + 0.75*avg_speed # minimize all terms
    except:
      reward = 0

    return reward

  def skip_steps(self, x):
    for _ in range(x): 
      traci.simulationStep()
      if self.use_gui:
        time.sleep(self.pause_time)

  def is_done(self):
    max_time = 500  # Example maximum simulation time
    return (traci.simulation.getTime() >= max_time or len(traci.vehicle.getIDList()) == 0) and self.deployed_counter != 0

  # METRICS:
  def calculate_congestion(self, vehicle_ids):
    congestion = 0
    current_time = traci.simulation.getTime()  # Get the current simulation time
    
    for vehicle_id in vehicle_ids:
      departure_time = traci.vehicle.getDeparture(vehicle_id)  # Get each vehicle's departure time
      speed = traci.vehicle.getSpeed(vehicle_id)  # Get the vehicle's current speed
      
      # Check if the vehicle is stopped and not just starting/departing
      if speed == 0 and current_time not in range(int(departure_time) - 1, int(departure_time) + 2):
          congestion += 1  # Increment congestion counter for stopped vehicles
  
    # update congestion log
    self.total_congestion_log.append(congestion)

    return congestion

  def calculate_mean_emission(self):
    total_emissions = sum(self.vehicle_emissions.values())
    num_vehicles = len(self.vehicle_emissions)
    try:
        return total_emissions / num_vehicles
    except:
        return 0

  def calculate_avg_wait_time(self, lane_ids):
    wait_times = []
    
    # total wait time of cars in all lanes
    for lane_id in lane_ids:
      # total wait time of all cars in one lane
      for vehicle_id in traci.lane.getLastStepVehicleIDs(lane_id):
          wait_time = traci.vehicle.getWaitingTime(vehicle_id)

          # update the wait log
          if vehicle_id in self.vehicle_wait_log:
            self.vehicle_wait_log[vehicle_id] = max(self.vehicle_wait_log[vehicle_id], wait_time) # only want the greatest average wait time for each vehicle
          else:
            self.vehicle_wait_log[vehicle_id] = wait_time

          wait_times.append(wait_time)
  
    avg_wait_time = sum(wait_times)/len(wait_times) if wait_times else 0
    
    return avg_wait_time

  def calculate_total_stops(self, lane_ids):
    total_stops = 0
    for lane_id in lane_ids:
      stops_in_lane = traci.lane.getLastStepHaltingNumber(lane_id)
      total_stops += stops_in_lane

    return total_stops
    
  def calculate_avg_speed(self, vehicle_ids):
    total_speed = sum(traci.vehicle.getSpeed(v_id) for v_id in vehicle_ids)
    avg_speed = total_speed / len(vehicle_ids) if vehicle_ids else 0

    # update total speed log
    self.total_speed_log.append(avg_speed)

    return avg_speed

  def spawn_random_car(self, step_counter):
    """
    Spawns a random car with a unique ID and assigns it a random route.
    edge_mapping represents the available routes that any car can take; start_edge:end_edge
    """
    edge_mapping = {
    #north traffic light
    '466414089#0': ['35519718#1', '182704478#1', '184789522#1'],
    
    #west traffic light
    '42684286':['35519718#1', '182704478#1', '184789522#1', '50876968#1'],
    
    #south traffic light
    '25634438#0':['35519718#1', '50876968#1', '184789522#1'],

    #east traffic light
    '35529041#1':['50876968#1', '35519718#1', '182704478#1']
    }
    
    vehicle_id = f"rand_car_{step_counter}"

    start_edge = random.choice(list(edge_mapping.keys()))
    end_edge = random.choice(edge_mapping[start_edge])

    route_id = f"route_{vehicle_id}"

    try:
        traci.route.add(routeID=route_id, edges=[start_edge, end_edge])

        # Add the vehicle to the simulation
        traci.vehicle.add(vehID=vehicle_id, routeID=route_id)

        #print(f"Deployed random vehicle {vehicle_id} from {start_edge} to {end_edge}")

        # Set a random speed for the vehicle
        traci.vehicle.setSpeed(vehicle_id, random.uniform(5, 15))

    except traci.TraCIException as e:
        pass
        #print(f"Failed to add vehicle {vehicle_id} on route from {start_edge} to {end_edge}: {e}")

# %% [markdown]
# ### Simulation with SUMO-GUI

# %%
'''
    The purpose of this is just to visualize our results!
    Explanation of SumoEnv parameters:
        use_gui = True runs with sumo gui
        use_gui = False runs sumo (all same functionality just doesn't render anything)
        use_random = False tells the env NOT to deploy random vehicles
        use_random = True tells the env to deploy random vehicles
        use_actions = False tells the env that we are running with random actions (note can ONLY use False here since we are using env.action_space.sample() later)
        use_actions = True tell the env that we are running with actions chosen by the agent (will NOT work yet since we don't have an agent!)
'''

env = SumoEnv(use_gui=False, use_random=True, use_actions=True) # use_gui=False sets sumo_binary to 'sumo' instead of 'sumo-gui'

episodes = 1 # note can only be run ONCE with sumo-gui!
score_log = []
wait_log = []
emissions_log = []
congestion_log = []
speed_log = []

for episode in range(1, episodes + 1):
    done = False
    truncated = False
    score = 0
    info = {}

    while not done:
        env.render()
        action = env.action_space.sample()
        state, reward, done, truncated, info = env.step(action)
        score += reward


    state, _ = env.reset()
    score_log.append(score)


    # Extract wait time metrics
    emissions_log.append(info["emissions"])
    wait_times = info.get("vehicle_wait_log", {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars if num_cars > 0 else 0
    wait_log.append(episode_mean_wait)

    # Extract congestion and speed metrics
    if info.get("total_congestion_avg") is not None:
        congestion_log.append(info["total_congestion_avg"])
    if info.get("total_speed_avg") is not None:
        speed_log.append(info["total_speed_avg"])

traci.close()

# Compute and print final metrics
mean_sample_score = np.mean(score_log)
mean_wait_time = np.mean(wait_log)
mean_congestion = np.mean(congestion_log) if congestion_log else None
mean_speed = np.mean(speed_log) if speed_log else None
mean_emissions = np.mean(emissions_log) if emissions_log else None

print(f"Mean Score over {episodes} episodes: {mean_sample_score}")
print(f"Mean wait time over {episodes} episodes: {mean_wait_time}")
print(f"Mean congestion over {episodes} episodes: {mean_congestion}")
print(f"Mean speed over {episodes} episodes: {mean_speed}")
print(f"Mean emissions over {episodes} episodes: {mean_emissions} milligrams (mg)")
# Out:
# Mean Score over 1 episodes: -994.7226978415877
# Mean wait time over 1 episodes: 15.594594594594595
# Mean congestion over 1 episodes: 1.2058823529411764
# Mean speed over 1 episodes: 3.563490518512286
# Mean emissions over 1 episodes: 2173.406452081074 milligrams (mg)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# CREATE NEW VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])
# Out:
# Deployed random vehicle rand_car_0 from 42684286 to 182704478#1
# Deployed random vehicle rand_car_0 from 25634438#0 to 50876968#1
# Deployed random vehicle rand_car_1 from 25634438#0 to 35519718#1
# Deployed random vehicle rand_car_2 from 466414089#0 to 184789522#1
# Deployed random vehicle rand_car_3 from 25634438#0 to 35519718#1
# Deployed random vehicle rand_car_4 from 42684286 to 50876968#1
# Deployed random vehicle rand_car_5 from 25634438#0 to 184789522#1
# Deployed random vehicle rand_car_6 from 25634438#0 to 50876968#1
# Deployed random vehicle rand_car_7 from 42684286 to 182704478#1
# Deployed random vehicle rand_car_8 from 35529041#1 to 50876968#1

# %%
# TRAIN AGENT
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
#check_env(env)
env = DummyVecEnv([lambda: env])
model = PPO("MlpPolicy", env, verbose=1)

spawn_rates = np.arange(0.05, 0.95, 0.1) 

for spawn_rate in spawn_rates:
    print(f"Training with spawn_rate: {spawn_rate}")

    env = SumoEnv(use_gui=False, use_random=True, use_actions=True, spawn_rate=spawn_rate)
    env.step(0)
    env = DummyVecEnv([lambda: env])

    model.set_env(env)

    model.learn(total_timesteps=5000)


# can change number of timesteps, however at least 10000 to make a semi-decent one
model.save("./agents/waterloo-agent-various-rates") # takes ~30 mins
# Out:
# Using cpu device
# Training with spawn_rate: 0.05
# -----------------------------
# | time/              |      |
# |    fps             | 4    |
# |    iterations      | 1    |
# |    time_elapsed    | 457  |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 2           |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012587607 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 1.08e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 3.13e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 3            |
# |    time_elapsed         | 1865         |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0129020475 |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 842          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 2e+04        |
# ------------------------------------------
# Training with spawn_rate: 0.15000000000000002
# -----------------------------
# | time/              |      |
# |    fps             | 0    |
# |    iterations      | 1    |
# |    time_elapsed    | 6015 |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 2             |
# |    time_elapsed         | 6513          |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 4.0248386e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.39e+04      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 7.77e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 0             |
# |    iterations           | 3             |
# |    time_elapsed         | 7052          |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00023328126 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.14e+04      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000884     |
# |    value_loss           | 1.49e+05      |
# -------------------------------------------
# Training with spawn_rate: 0.25000000000000006
# -----------------------------
# | time/              |      |
# |    fps             | 3    |
# |    iterations      | 1    |
# |    time_elapsed    | 532  |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 2             |
# |    time_elapsed         | 1078          |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00022360502 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.35         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.23e+04      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000753     |
# |    value_loss           | 6.99e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 3             |
# |    time_elapsed         | 1623          |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00018088554 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.92e+04      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000476     |
# |    value_loss           | 5.28e+04      |
# -------------------------------------------
# Training with spawn_rate: 0.35000000000000003
# -----------------------------
# | time/              |      |
# |    fps             | 3    |
# |    iterations      | 1    |
# |    time_elapsed    | 545  |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3             |
# |    iterations           | 2             |
# |    time_elapsed         | 1094          |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00017993688 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.14e+04      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00042      |
# |    value_loss           | 6.26e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 3            |
# |    time_elapsed         | 1648         |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0007877224 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000902    |
# |    value_loss           | 3.42e+04     |
# ------------------------------------------
# Training with spawn_rate: 0.45000000000000007
# -----------------------------
# | time/              |      |
# |    fps             | 3    |
# |    iterations      | 1    |
# |    time_elapsed    | 540  |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2            |
# |    iterations           | 2            |
# |    time_elapsed         | 1370         |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.835074e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00012     |
# |    value_loss           | 4.04e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1             |
# |    iterations           | 3             |
# |    time_elapsed         | 3585          |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00055688765 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.75e+04      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00051      |
# |    value_loss           | 5.42e+04      |
# -------------------------------------------
# Training with spawn_rate: 0.5500000000000002
# -----------------------------
# | time/              |      |
# |    fps             | 1    |
# |    iterations      | 1    |
# |    time_elapsed    | 1171 |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1             |
# |    iterations           | 2             |
# |    time_elapsed         | 2401          |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00097588764 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.13e+04      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000659     |
# |    value_loss           | 5.68e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2            |
# |    iterations           | 3            |
# |    time_elapsed         | 2784         |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0008258848 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+04      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000333    |
# |    value_loss           | 5.06e+04     |
# ------------------------------------------
# Training with spawn_rate: 0.6500000000000001
# -----------------------------
# | time/              |      |
# |    fps             | 9    |
# |    iterations      | 1    |
# |    time_elapsed    | 214  |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 2           |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010498432 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.74e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 4.69e+04    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 3         |
# |    time_elapsed         | 621       |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0099366 |
# |    clip_fraction        | 0.0182    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.35     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.46e+04  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.00438  |
# |    value_loss           | 3.81e+04  |
# ---------------------------------------
# Training with spawn_rate: 0.7500000000000002
# -----------------------------
# | time/              |      |
# |    fps             | 7    |
# |    iterations      | 1    |
# |    time_elapsed    | 274  |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 2           |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005988392 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 6.89e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 976          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0039379476 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 2.93e+04     |
# ------------------------------------------
# Training with spawn_rate: 0.8500000000000002
# ------------------------------
# | time/              |       |
# |    fps             | 0     |
# |    iterations      | 1     |
# |    time_elapsed    | 73404 |
# |    total_timesteps | 2048  |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 0            |
# |    iterations           | 2            |
# |    time_elapsed         | 74605        |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036533717 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.62e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 6.13e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 3           |
# |    time_elapsed         | 75799       |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008056731 |
# |    clip_fraction        | 0.00615     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.24e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 5.52e+04    |
# -----------------------------------------

# %%
# SAVE THE MODEL
model.save("waterloo-model") # creates .zip in current working directory

# %%
loaded_model = PPO.load("waterloo-model")

# %%
# CREATE VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
#check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODES
num_test_episodes = 15
all_scores = []
wait_log = []
# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0
    info = {}
    while not done:
        action, _states = loaded_model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)

    print(info)
    wait_times = info[0].get('vehicle_wait_log', {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars
    wait_log.append(episode_mean_wait)

traci.close()
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")
print(f"Mean wait time over {num_test_episodes} episodes: {np.mean(wait_log)}")
# Out:
# [{'vehicle_wait_log': {'rand_car_0': 0.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 0.0, 'rand_car_4': 300.0, 'rand_car_5': 300.0, 'rand_car_6': 300.0, 'rand_car_7': 0.0, 'rand_car_8': 298.0, 'rand_car_9': 300.0, 'rand_car_10': 288.0, 'rand_car_11': 0.0, 'rand_car_12': 0.0, 'rand_car_13': 277.0, 'rand_car_14': 300.0, 'rand_car_15': 0.0, 'rand_car_17': 265.0, 'rand_car_18': 272.0, 'rand_car_16': 0.0, 'rand_car_19': 265.0, 'rand_car_20': 300.0, 'rand_car_21': 0.0, 'rand_car_22': 300.0, 'rand_car_23': 300.0, 'rand_car_24': 0.0, 'rand_car_25': 0.0, 'rand_car_26': 246.0, 'rand_car_27': 254.0, 'rand_car_28': 247.0, 'rand_car_29': 253.0, 'rand_car_30': 240.0, 'rand_car_31': 252.0, 'rand_car_32': 250.0, 'rand_car_33': 247.0, 'rand_car_34': 0.0, 'rand_car_35': 269.0, 'rand_car_36': 0.0, 'rand_car_37': 237.0, 'rand_car_38': 240.0, 'rand_car_39': 238.0, 'rand_car_40': 0.0, 'rand_car_41': 219.0, 'rand_car_42': 300.0, 'rand_car_43': 270.0, 'rand_car_44': 236.0, 'rand_car_45': 216.0, 'rand_car_46': 253.0, 'rand_car_47': 216.0, 'rand_car_48': 263.0, 'rand_car_49': 251.0, 'rand_car_50': 213.0, 'rand_car_51': 277.0, 'rand_car_52': 0.0, 'rand_car_53': 0.0, 'rand_car_54': 247.0, 'rand_car_55': 202.0, 'rand_car_56': 0.0, 'rand_car_57': 0.0, 'rand_car_58': 0.0, 'rand_car_59': 0.0, 'rand_car_60': 268.0, 'rand_car_61': 192.0, 'rand_car_62': 166.0, 'rand_car_63': 190.0, 'rand_car_64': 0.0, 'rand_car_65': 0.0, 'rand_car_66': 189.0, 'rand_car_67': 258.0, 'rand_car_68': 258.0, 'rand_car_71': 0.0, 'rand_car_72': 158.0, 'rand_car_74': 0.0, 'rand_car_75': 167.0, 'rand_car_76': 167.0, 'rand_car_78': 157.0, 'rand_car_80': 164.0, 'rand_car_82': 0.0, 'rand_car_83': 0.0, 'rand_car_85': 156.0, 'rand_car_86': 158.0, 'rand_car_87': 228.0, 'rand_car_88': 155.0, 'rand_car_89': 159.0, 'rand_car_90': 0.0, 'rand_car_91': 154.0, 'rand_car_92': 155.0, 'rand_car_94': 0.0, 'rand_car_95': 154.0, 'rand_car_96': 149.0, 'rand_car_97': 0.0, 'rand_car_99': 0.0, 'rand_car_69': 160.0}, 'total_congestion_avg': 33.97560975609756, 'total_speed_avg': 1.2239629130432752, 'emissions': 2549.187481007429, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.2200000e+00, 6.4454999e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.2000000e-01, 1.2000000e-01,
#        1.9140000e+00, 1.0936545e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9999999e-02, 2.9999999e-02,
#        4.1100001e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        6.3999999e-01, 1.7597015e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1410000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1390001e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        4.1000000e-01, 1.1000114e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.3900001e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 300.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 300.0, 'rand_car_6': 287.0, 'rand_car_7': 0.0, 'rand_car_9': 0.0, 'rand_car_8': 0.0, 'rand_car_10': 0.0, 'rand_car_11': 284.0, 'rand_car_12': 279.0, 'rand_car_13': 277.0, 'rand_car_14': 0.0, 'rand_car_15': 268.0, 'rand_car_16': 275.0, 'rand_car_17': 268.0, 'rand_car_18': 272.0, 'rand_car_19': 300.0, 'rand_car_20': 261.0, 'rand_car_21': 266.0, 'rand_car_22': 256.0, 'rand_car_23': 300.0, 'rand_car_24': 255.0, 'rand_car_25': 0.0, 'rand_car_26': 254.0, 'rand_car_27': 246.0, 'rand_car_28': 246.0, 'rand_car_29': 250.0, 'rand_car_31': 0.0, 'rand_car_30': 253.0, 'rand_car_32': 0.0, 'rand_car_33': 278.0, 'rand_car_34': 279.0, 'rand_car_35': 0.0, 'rand_car_36': 0.0, 'rand_car_37': 0.0, 'rand_car_38': 227.0, 'rand_car_39': 270.0, 'rand_car_40': 233.0, 'rand_car_41': 0.0, 'rand_car_42': 227.0, 'rand_car_43': 218.0, 'rand_car_44': 253.0, 'rand_car_45': 223.0, 'rand_car_46': 214.0, 'rand_car_47': 0.0, 'rand_car_48': 0.0, 'rand_car_49': 208.0, 'rand_car_50': 246.0, 'rand_car_51': 186.0, 'rand_car_52': 0.0, 'rand_car_53': 198.0, 'rand_car_54': 186.0, 'rand_car_55': 182.0, 'rand_car_56': 191.0, 'rand_car_57': 185.0, 'rand_car_58': 0.0, 'rand_car_59': 0.0, 'rand_car_60': 177.0, 'rand_car_62': 183.0, 'rand_car_64': 208.0, 'rand_car_61': 0.0, 'rand_car_65': 173.0, 'rand_car_63': 0.0, 'rand_car_66': 169.0, 'rand_car_67': 171.0, 'rand_car_68': 170.0, 'rand_car_69': 208.0, 'rand_car_70': 167.0, 'rand_car_71': 0.0, 'rand_car_72': 0.0, 'rand_car_73': 0.0, 'rand_car_74': 163.0, 'rand_car_75': 165.0, 'rand_car_76': 180.0, 'rand_car_77': 164.0, 'rand_car_78': 0.0, 'rand_car_79': 0.0, 'rand_car_82': 163.0, 'rand_car_86': 162.0, 'rand_car_88': 0.0, 'rand_car_90': 164.0, 'rand_car_89': 0.0, 'rand_car_91': 163.0, 'rand_car_93': 0.0, 'rand_car_94': 161.0, 'rand_car_95': 160.0, 'rand_car_98': 0.0, 'rand_car_99': 162.0, 'rand_car_80': 142.0, 'rand_car_81': 131.0, 'rand_car_83': 176.0, 'rand_car_84': 130.0, 'rand_car_85': 140.0, 'rand_car_87': 129.0, 'rand_car_92': 130.0, 'rand_car_96': 127.0}, 'total_congestion_avg': 36.353658536585364, 'total_speed_avg': 1.1153516543653383, 'emissions': 2629.360467839766, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 9.0000004e-02, 9.0000004e-02,
#        1.4760000e+00, 6.2181390e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.1000000e-01, 1.1000000e-01,
#        1.8260000e+00, 9.1447371e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0360000e+00, 2.5138593e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        9.1900003e-01, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2220000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0290000e+00, 1.8333524e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1740000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0050000e+00, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 299.0, 'rand_car_2': 300.0, 'rand_car_1': 300.0, 'rand_car_3': 0.0, 'rand_car_5': 299.0, 'rand_car_4': 0.0, 'rand_car_6': 0.0, 'rand_car_7': 297.0, 'rand_car_8': 300.0, 'rand_car_9': 300.0, 'rand_car_10': 282.0, 'rand_car_12': 288.0, 'rand_car_13': 300.0, 'rand_car_11': 0.0, 'rand_car_14': 300.0, 'rand_car_15': 300.0, 'rand_car_16': 0.0, 'rand_car_17': 0.0, 'rand_car_18': 286.0, 'rand_car_19': 0.0, 'rand_car_21': 264.0, 'rand_car_20': 0.0, 'rand_car_22': 258.0, 'rand_car_23': 263.0, 'rand_car_24': 259.0, 'rand_car_25': 0.0, 'rand_car_26': 270.0, 'rand_car_27': 0.0, 'rand_car_28': 264.0, 'rand_car_29': 243.0, 'rand_car_31': 233.0, 'rand_car_30': 241.0, 'rand_car_32': 232.0, 'rand_car_33': 258.0, 'rand_car_34': 300.0, 'rand_car_35': 300.0, 'rand_car_36': 300.0, 'rand_car_37': 237.0, 'rand_car_38': 237.0, 'rand_car_39': 235.0, 'rand_car_40': 234.0, 'rand_car_41': 227.0, 'rand_car_42': 221.0, 'rand_car_43': 201.0, 'rand_car_44': 0.0, 'rand_car_45': 223.0, 'rand_car_46': 218.0, 'rand_car_47': 222.0, 'rand_car_50': 0.0, 'rand_car_52': 228.0, 'rand_car_54': 208.0, 'rand_car_55': 220.0, 'rand_car_57': 203.0, 'rand_car_58': 0.0, 'rand_car_59': 0.0, 'rand_car_60': 219.0, 'rand_car_61': 204.0, 'rand_car_62': 0.0, 'rand_car_63': 210.0, 'rand_car_64': 0.0, 'rand_car_66': 195.0, 'rand_car_68': 188.0, 'rand_car_69': 0.0, 'rand_car_72': 186.0, 'rand_car_74': 166.0, 'rand_car_76': 181.0, 'rand_car_80': 162.0, 'rand_car_81': 0.0, 'rand_car_83': 0.0, 'rand_car_84': 159.0, 'rand_car_85': 161.0, 'rand_car_86': 0.0, 'rand_car_87': 0.0, 'rand_car_88': 154.0, 'rand_car_90': 153.0, 'rand_car_91': 0.0, 'rand_car_92': 0.0, 'rand_car_94': 159.0, 'rand_car_95': 152.0, 'rand_car_96': 0.0, 'rand_car_97': 0.0, 'rand_car_98': 151.0, 'rand_car_99': 0.0, 'rand_car_48': 163.0, 'rand_car_49': 104.0, 'rand_car_51': 162.0, 'rand_car_53': 103.0, 'rand_car_56': 102.0, 'rand_car_65': 169.0}, 'total_congestion_avg': 33.47764227642276, 'total_speed_avg': 0.9714473852288774, 'emissions': 2745.527718486597, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.4200002e-01, 8.5940003e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.2000000e-01, 1.2000000e-01,
#        2.0100000e+00, 8.5496098e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        5.1999998e-01, 1.7597015e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        8.1999999e-01, 1.7597015e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2640001e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0270000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        9.7799999e-01, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0850000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_2': 0.0, 'rand_car_3': 0.0, 'rand_car_4': 300.0, 'rand_car_5': 0.0, 'rand_car_6': 300.0, 'rand_car_7': 300.0, 'rand_car_8': 300.0, 'rand_car_9': 285.0, 'rand_car_10': 0.0, 'rand_car_11': 280.0, 'rand_car_12': 0.0, 'rand_car_13': 0.0, 'rand_car_14': 282.0, 'rand_car_15': 281.0, 'rand_car_16': 0.0, 'rand_car_17': 0.0, 'rand_car_18': 261.0, 'rand_car_19': 0.0, 'rand_car_20': 300.0, 'rand_car_21': 0.0, 'rand_car_22': 0.0, 'rand_car_23': 287.0, 'rand_car_24': 300.0, 'rand_car_25': 247.0, 'rand_car_26': 0.0, 'rand_car_27': 266.0, 'rand_car_28': 257.0, 'rand_car_29': 245.0, 'rand_car_30': 266.0, 'rand_car_31': 0.0, 'rand_car_32': 293.0, 'rand_car_33': 238.0, 'rand_car_34': 286.0, 'rand_car_35': 239.0, 'rand_car_36': 268.0, 'rand_car_37': 244.0, 'rand_car_38': 279.0, 'rand_car_39': 0.0, 'rand_car_40': 0.0, 'rand_car_41': 218.0, 'rand_car_42': 0.0, 'rand_car_43': 223.0, 'rand_car_44': 0.0, 'rand_car_46': 260.0, 'rand_car_47': 300.0, 'rand_car_45': 0.0, 'rand_car_48': 212.0, 'rand_car_49': 0.0, 'rand_car_50': 0.0, 'rand_car_51': 213.0, 'rand_car_52': 213.0, 'rand_car_53': 250.0, 'rand_car_54': 0.0, 'rand_car_55': 209.0, 'rand_car_56': 208.0, 'rand_car_57': 207.0, 'rand_car_58': 193.0, 'rand_car_59': 188.0, 'rand_car_60': 219.0, 'rand_car_61': 205.0, 'rand_car_62': 192.0, 'rand_car_63': 192.0, 'rand_car_64': 184.0, 'rand_car_65': 190.0, 'rand_car_66': 176.0, 'rand_car_67': 0.0, 'rand_car_68': 188.0, 'rand_car_69': 198.0, 'rand_car_70': 0.0, 'rand_car_71': 252.0, 'rand_car_72': 0.0, 'rand_car_73': 168.0, 'rand_car_74': 0.0, 'rand_car_75': 169.0, 'rand_car_76': 167.0, 'rand_car_77': 300.0, 'rand_car_78': 0.0, 'rand_car_79': 163.0, 'rand_car_80': 151.0, 'rand_car_81': 0.0, 'rand_car_82': 0.0, 'rand_car_83': 0.0, 'rand_car_84': 148.0, 'rand_car_85': 170.0, 'rand_car_86': 0.0, 'rand_car_87': 147.0, 'rand_car_88': 155.0, 'rand_car_89': 145.0, 'rand_car_90': 145.0, 'rand_car_91': 0.0, 'rand_car_92': 300.0, 'rand_car_93': 175.0, 'rand_car_94': 146.0, 'rand_car_95': 0.0, 'rand_car_96': 167.0, 'rand_car_97': 155.0, 'rand_car_98': 174.0, 'rand_car_99': 289.0}, 'total_congestion_avg': 35.21951219512195, 'total_speed_avg': 1.2374486750939617, 'emissions': 2524.718757452656, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        9.7299999e-01, 4.9108571e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 2.0000000e-02, 2.0000000e-02,
#        2.1000000e-02, 2.8643229e-16, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.2000000e-01, 1.2000000e-01,
#        2.0070000e+00, 8.5496098e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 9.9999998e-03, 9.9999998e-03,
#        8.9000002e-02, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9999999e-02, 2.9999999e-02,
#        5.0400001e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0590000e+00, 2.9328357e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        5.4200000e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        9.6600002e-01, 1.3750143e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1520000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 299.0, 'rand_car_6': 298.0, 'rand_car_7': 300.0, 'rand_car_8': 0.0, 'rand_car_9': 300.0, 'rand_car_10': 0.0, 'rand_car_11': 0.0, 'rand_car_12': 300.0, 'rand_car_13': 288.0, 'rand_car_14': 0.0, 'rand_car_15': 283.0, 'rand_car_16': 295.0, 'rand_car_17': 300.0, 'rand_car_18': 253.0, 'rand_car_19': 249.0, 'rand_car_20': 244.0, 'rand_car_21': 288.0, 'rand_car_22': 277.0, 'rand_car_23': 265.0, 'rand_car_24': 0.0, 'rand_car_25': 238.0, 'rand_car_26': 0.0, 'rand_car_27': 261.0, 'rand_car_28': 264.0, 'rand_car_29': 269.0, 'rand_car_30': 255.0, 'rand_car_31': 225.0, 'rand_car_32': 0.0, 'rand_car_33': 218.0, 'rand_car_34': 224.0, 'rand_car_35': 255.0, 'rand_car_36': 216.0, 'rand_car_37': 226.0, 'rand_car_38': 241.0, 'rand_car_39': 0.0, 'rand_car_40': 201.0, 'rand_car_41': 222.0, 'rand_car_42': 0.0, 'rand_car_43': 0.0, 'rand_car_44': 0.0, 'rand_car_45': 0.0, 'rand_car_46': 203.0, 'rand_car_47': 231.0, 'rand_car_48': 191.0, 'rand_car_49': 186.0, 'rand_car_50': 185.0, 'rand_car_51': 180.0, 'rand_car_52': 214.0, 'rand_car_53': 358.0, 'rand_car_54': 202.0, 'rand_car_55': 179.0, 'rand_car_56': 176.0, 'rand_car_57': 0.0, 'rand_car_60': 0.0, 'rand_car_61': 0.0, 'rand_car_63': 203.0, 'rand_car_64': 168.0, 'rand_car_68': 0.0, 'rand_car_69': 0.0, 'rand_car_70': 161.0, 'rand_car_72': 188.0, 'rand_car_73': 188.0, 'rand_car_74': 165.0, 'rand_car_76': 0.0, 'rand_car_77': 153.0, 'rand_car_78': 176.0, 'rand_car_80': 176.0, 'rand_car_81': 152.0, 'rand_car_83': 154.0, 'rand_car_84': 170.0, 'rand_car_85': 164.0, 'rand_car_86': 0.0, 'rand_car_87': 164.0, 'rand_car_88': 163.0, 'rand_car_90': 0.0, 'rand_car_91': 153.0, 'rand_car_92': 152.0, 'rand_car_94': 151.0, 'rand_car_95': 271.0, 'rand_car_98': 0.0, 'rand_car_99': 0.0, 'rand_car_58': 143.0, 'rand_car_59': 142.0, 'rand_car_62': 171.0}, 'total_congestion_avg': 34.7479674796748, 'total_speed_avg': 1.0613174338340887, 'emissions': 2550.6799642799856, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        4.7400001e-01, 8.5940003e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.3320000e+00, 1.0741211e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        1.0720000e+00, 1.7597015e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        7.2000003e-01, 1.7597015e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2359999e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1040000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.0340000e+00, 1.3750143e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        9.8799998e-01, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 300.0, 'rand_car_2': 341.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 0.0, 'rand_car_6': 333.0, 'rand_car_7': 290.0, 'rand_car_8': 300.0, 'rand_car_9': 300.0, 'rand_car_10': 300.0, 'rand_car_11': 286.0, 'rand_car_12': 300.0, 'rand_car_13': 0.0, 'rand_car_14': 298.0, 'rand_car_15': 280.0, 'rand_car_16': 289.0, 'rand_car_18': 308.0, 'rand_car_17': 0.0, 'rand_car_19': 300.0, 'rand_car_20': 269.0, 'rand_car_21': 0.0, 'rand_car_22': 282.0, 'rand_car_23': 0.0, 'rand_car_24': 270.0, 'rand_car_25': 264.0, 'rand_car_26': 292.0, 'rand_car_27': 291.0, 'rand_car_28': 255.0, 'rand_car_29': 256.0, 'rand_car_30': 0.0, 'rand_car_31': 0.0, 'rand_car_32': 248.0, 'rand_car_33': 242.0, 'rand_car_34': 248.0, 'rand_car_35': 235.0, 'rand_car_36': 225.0, 'rand_car_37': 0.0, 'rand_car_38': 240.0, 'rand_car_39': 0.0, 'rand_car_40': 226.0, 'rand_car_41': 237.0, 'rand_car_42': 230.0, 'rand_car_43': 205.0, 'rand_car_44': 223.0, 'rand_car_45': 254.0, 'rand_car_46': 0.0, 'rand_car_48': 0.0, 'rand_car_49': 0.0, 'rand_car_51': 0.0, 'rand_car_53': 0.0, 'rand_car_54': 0.0, 'rand_car_56': 208.0, 'rand_car_57': 189.0, 'rand_car_59': 184.0, 'rand_car_60': 196.0, 'rand_car_63': 193.0, 'rand_car_64': 0.0, 'rand_car_65': 0.0, 'rand_car_67': 193.0, 'rand_car_66': 0.0, 'rand_car_69': 190.0, 'rand_car_70': 190.0, 'rand_car_71': 187.0, 'rand_car_72': 176.0, 'rand_car_73': 169.0, 'rand_car_74': 300.0, 'rand_car_77': 0.0, 'rand_car_79': 172.0, 'rand_car_80': 173.0, 'rand_car_81': 171.0, 'rand_car_83': 159.0, 'rand_car_85': 0.0, 'rand_car_86': 168.0, 'rand_car_87': 0.0, 'rand_car_89': 164.0, 'rand_car_90': 163.0, 'rand_car_91': 144.0, 'rand_car_92': 0.0, 'rand_car_94': 145.0, 'rand_car_95': 143.0, 'rand_car_97': 164.0, 'rand_car_98': 144.0, 'rand_car_99': 163.0, 'rand_car_47': 133.0, 'rand_car_50': 132.0, 'rand_car_52': 136.0}, 'total_congestion_avg': 35.75609756097561, 'total_speed_avg': 0.9279432229606803, 'emissions': 2471.7908534967332, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        7.2500002e-01, 1.0312800e-16, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.0000000e-01, 1.0000000e-01,
#        2.4500000e-01, 1.2923534e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        8.4399998e-01, 1.7597015e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.0000000e-02, 2.0000000e-02,
#        2.6499999e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        9.9100000e-01, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1180000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2040000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.6899998e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 0.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_4': 0.0, 'rand_car_5': 300.0, 'rand_car_3': 286.0, 'rand_car_6': 300.0, 'rand_car_7': 295.0, 'rand_car_8': 300.0, 'rand_car_9': 300.0, 'rand_car_10': 0.0, 'rand_car_11': 0.0, 'rand_car_12': 0.0, 'rand_car_13': 300.0, 'rand_car_14': 300.0, 'rand_car_15': 294.0, 'rand_car_16': 0.0, 'rand_car_17': 283.0, 'rand_car_18': 0.0, 'rand_car_19': 300.0, 'rand_car_20': 282.0, 'rand_car_21': 275.0, 'rand_car_22': 268.0, 'rand_car_23': 261.0, 'rand_car_24': 270.0, 'rand_car_25': 262.0, 'rand_car_26': 0.0, 'rand_car_27': 270.0, 'rand_car_28': 269.0, 'rand_car_29': 0.0, 'rand_car_30': 253.0, 'rand_car_31': 261.0, 'rand_car_32': 255.0, 'rand_car_33': 260.0, 'rand_car_34': 235.0, 'rand_car_35': 0.0, 'rand_car_36': 257.0, 'rand_car_37': 0.0, 'rand_car_38': 251.0, 'rand_car_39': 240.0, 'rand_car_40': 246.0, 'rand_car_41': 0.0, 'rand_car_42': 227.0, 'rand_car_43': 255.0, 'rand_car_44': 0.0, 'rand_car_45': 248.0, 'rand_car_46': 0.0, 'rand_car_47': 0.0, 'rand_car_48': 226.0, 'rand_car_49': 0.0, 'rand_car_50': 0.0, 'rand_car_51': 0.0, 'rand_car_52': 0.0, 'rand_car_53': 203.0, 'rand_car_54': 223.0, 'rand_car_55': 0.0, 'rand_car_56': 195.0, 'rand_car_57': 0.0, 'rand_car_58': 191.0, 'rand_car_59': 0.0, 'rand_car_60': 0.0, 'rand_car_61': 0.0, 'rand_car_63': 211.0, 'rand_car_62': 175.0, 'rand_car_64': 0.0, 'rand_car_65': 0.0, 'rand_car_66': 0.0, 'rand_car_67': 0.0, 'rand_car_68': 183.0, 'rand_car_69': 199.0, 'rand_car_70': 183.0, 'rand_car_71': 176.0, 'rand_car_72': 159.0, 'rand_car_74': 178.0, 'rand_car_73': 0.0, 'rand_car_75': 0.0, 'rand_car_76': 166.0, 'rand_car_77': 0.0, 'rand_car_78': 166.0, 'rand_car_79': 0.0, 'rand_car_80': 175.0, 'rand_car_81': 0.0, 'rand_car_83': 0.0, 'rand_car_84': 163.0, 'rand_car_86': 166.0, 'rand_car_87': 163.0, 'rand_car_88': 162.0, 'rand_car_89': 0.0, 'rand_car_90': 165.0, 'rand_car_91': 162.0, 'rand_car_92': 161.0, 'rand_car_93': 158.0, 'rand_car_94': 0.0, 'rand_car_96': 153.0, 'rand_car_97': 0.0, 'rand_car_98': 155.0, 'rand_car_82': 174.0}, 'total_congestion_avg': 34.172764227642276, 'total_speed_avg': 1.1517301651177305, 'emissions': 2579.166300860294, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1270000e+00, 7.3662856e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.2280000e+00, 1.0741211e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.4999998e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9999999e-02, 2.9999999e-02,
#        5.2800000e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2390000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        5.5800003e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1390001e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.6300000e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 291.0, 'rand_car_6': 300.0, 'rand_car_7': 0.0, 'rand_car_8': 0.0, 'rand_car_9': 299.0, 'rand_car_10': 300.0, 'rand_car_11': 300.0, 'rand_car_12': 0.0, 'rand_car_13': 281.0, 'rand_car_14': 303.0, 'rand_car_15': 282.0, 'rand_car_16': 283.0, 'rand_car_17': 0.0, 'rand_car_18': 0.0, 'rand_car_19': 272.0, 'rand_car_20': 0.0, 'rand_car_21': 260.0, 'rand_car_22': 274.0, 'rand_car_23': 254.0, 'rand_car_24': 263.0, 'rand_car_25': 252.0, 'rand_car_26': 0.0, 'rand_car_27': 300.0, 'rand_car_28': 268.0, 'rand_car_29': 247.0, 'rand_car_30': 241.0, 'rand_car_31': 0.0, 'rand_car_32': 0.0, 'rand_car_33': 0.0, 'rand_car_35': 238.0, 'rand_car_34': 0.0, 'rand_car_36': 0.0, 'rand_car_37': 234.0, 'rand_car_38': 0.0, 'rand_car_39': 0.0, 'rand_car_40': 0.0, 'rand_car_41': 239.0, 'rand_car_42': 241.0, 'rand_car_43': 236.0, 'rand_car_44': 271.0, 'rand_car_45': 0.0, 'rand_car_46': 224.0, 'rand_car_47': 0.0, 'rand_car_49': 217.0, 'rand_car_48': 212.0, 'rand_car_50': 217.0, 'rand_car_51': 212.0, 'rand_car_52': 208.0, 'rand_car_53': 217.0, 'rand_car_54': 0.0, 'rand_car_55': 203.0, 'rand_car_56': 0.0, 'rand_car_57': 208.0, 'rand_car_58': 0.0, 'rand_car_59': 0.0, 'rand_car_60': 187.0, 'rand_car_61': 193.0, 'rand_car_62': 187.0, 'rand_car_63': 0.0, 'rand_car_65': 189.0, 'rand_car_64': 183.0, 'rand_car_66': 0.0, 'rand_car_67': 195.0, 'rand_car_68': 0.0, 'rand_car_69': 176.0, 'rand_car_72': 167.0, 'rand_car_77': 163.0, 'rand_car_78': 158.0, 'rand_car_79': 0.0, 'rand_car_80': 149.0, 'rand_car_81': 300.0, 'rand_car_82': 0.0, 'rand_car_85': 150.0, 'rand_car_86': 295.0, 'rand_car_87': 0.0, 'rand_car_88': 0.0, 'rand_car_89': 161.0, 'rand_car_90': 0.0, 'rand_car_94': 0.0, 'rand_car_95': 149.0, 'rand_car_96': 0.0, 'rand_car_98': 174.0, 'rand_car_99': 148.0, 'rand_car_70': 123.0, 'rand_car_71': 165.0, 'rand_car_73': 122.0, 'rand_car_74': 163.0}, 'total_congestion_avg': 32.98170731707317, 'total_speed_avg': 1.124715504346776, 'emissions': 2612.8376343010314, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0779999e+00, 7.3662856e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.8100001e-01, 1.9095487e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9999999e-02, 2.9999999e-02,
#        3.6899999e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0050000e+00, 2.9328357e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2340000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        5.3399998e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0820000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.2750000e+00, 1.5628711e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 0.0, 'rand_car_4': 300.0, 'rand_car_5': 300.0, 'rand_car_6': 0.0, 'rand_car_7': 0.0, 'rand_car_8': 0.0, 'rand_car_9': 300.0, 'rand_car_10': 294.0, 'rand_car_11': 300.0, 'rand_car_12': 0.0, 'rand_car_13': 0.0, 'rand_car_14': 288.0, 'rand_car_15': 288.0, 'rand_car_16': 0.0, 'rand_car_17': 300.0, 'rand_car_18': 0.0, 'rand_car_19': 0.0, 'rand_car_20': 0.0, 'rand_car_21': 276.0, 'rand_car_22': 247.0, 'rand_car_23': 0.0, 'rand_car_24': 270.0, 'rand_car_25': 0.0, 'rand_car_26': 249.0, 'rand_car_27': 0.0, 'rand_car_28': 275.0, 'rand_car_29': 0.0, 'rand_car_30': 0.0, 'rand_car_31': 236.0, 'rand_car_32': 249.0, 'rand_car_33': 233.0, 'rand_car_34': 0.0, 'rand_car_35': 235.0, 'rand_car_37': 0.0, 'rand_car_36': 300.0, 'rand_car_38': 234.0, 'rand_car_39': 223.0, 'rand_car_40': 300.0, 'rand_car_41': 237.0, 'rand_car_42': 0.0, 'rand_car_43': 209.0, 'rand_car_44': 223.0, 'rand_car_45': 223.0, 'rand_car_46': 0.0, 'rand_car_47': 200.0, 'rand_car_48': 220.0, 'rand_car_49': 200.0, 'rand_car_50': 195.0, 'rand_car_51': 0.0, 'rand_car_52': 216.0, 'rand_car_53': 0.0, 'rand_car_54': 0.0, 'rand_car_55': 188.0, 'rand_car_56': 190.0, 'rand_car_57': 206.0, 'rand_car_58': 300.0, 'rand_car_59': 0.0, 'rand_car_60': 205.0, 'rand_car_61': 210.0, 'rand_car_62': 0.0, 'rand_car_63': 205.0, 'rand_car_64': 194.0, 'rand_car_65': 251.0, 'rand_car_66': 0.0, 'rand_car_67': 1.0, 'rand_car_68': 240.0, 'rand_car_69': 254.0, 'rand_car_71': 165.0, 'rand_car_72': 175.0, 'rand_car_70': 0.0, 'rand_car_73': 0.0, 'rand_car_74': 176.0, 'rand_car_75': 182.0, 'rand_car_76': 175.0, 'rand_car_77': 235.0, 'rand_car_79': 178.0, 'rand_car_80': 0.0, 'rand_car_81': 0.0, 'rand_car_82': 159.0, 'rand_car_83': 228.0, 'rand_car_84': 225.0, 'rand_car_85': 0.0, 'rand_car_88': 1.0, 'rand_car_89': 164.0, 'rand_car_90': 0.0, 'rand_car_91': 0.0, 'rand_car_92': 148.0, 'rand_car_93': 133.0, 'rand_car_94': 147.0, 'rand_car_95': 0.0, 'rand_car_97': 0.0, 'rand_car_98': 159.0, 'rand_car_78': 174.0, 'rand_car_86': 173.0}, 'total_congestion_avg': 28.453252032520325, 'total_speed_avg': 1.2707983970799337, 'emissions': 2563.3182020212025, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        3.9899999e-01, 8.5940003e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.0000000e-01, 1.0000000e-01,
#        8.5500002e-01, 1.2923534e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0650001e+00, 2.9328357e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2320000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0760000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        6.8000001e-01, 1.1000114e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.8900002e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 300.0, 'rand_car_3': 300.0, 'rand_car_2': 0.0, 'rand_car_5': 293.0, 'rand_car_4': 300.0, 'rand_car_7': 300.0, 'rand_car_6': 0.0, 'rand_car_8': 293.0, 'rand_car_9': 290.0, 'rand_car_10': 300.0, 'rand_car_11': 293.0, 'rand_car_12': 300.0, 'rand_car_13': 300.0, 'rand_car_14': 0.0, 'rand_car_15': 0.0, 'rand_car_16': 0.0, 'rand_car_17': 276.0, 'rand_car_18': 280.0, 'rand_car_19': 268.0, 'rand_car_21': 279.0, 'rand_car_20': 269.0, 'rand_car_22': 300.0, 'rand_car_23': 275.0, 'rand_car_24': 270.0, 'rand_car_25': 0.0, 'rand_car_26': 0.0, 'rand_car_27': 259.0, 'rand_car_28': 281.0, 'rand_car_29': 253.0, 'rand_car_30': 0.0, 'rand_car_31': 0.0, 'rand_car_32': 247.0, 'rand_car_33': 256.0, 'rand_car_34': 235.0, 'rand_car_35': 0.0, 'rand_car_36': 271.0, 'rand_car_37': 241.0, 'rand_car_38': 0.0, 'rand_car_39': 225.0, 'rand_car_40': 261.0, 'rand_car_41': 222.0, 'rand_car_42': 233.0, 'rand_car_43': 0.0, 'rand_car_44': 221.0, 'rand_car_45': 220.0, 'rand_car_46': 221.0, 'rand_car_47': 205.0, 'rand_car_48': 0.0, 'rand_car_49': 0.0, 'rand_car_50': 0.0, 'rand_car_51': 0.0, 'rand_car_52': 0.0, 'rand_car_53': 0.0, 'rand_car_54': 204.0, 'rand_car_55': 230.0, 'rand_car_56': 193.0, 'rand_car_57': 194.0, 'rand_car_58': 172.0, 'rand_car_59': 199.0, 'rand_car_60': 184.0, 'rand_car_61': 168.0, 'rand_car_63': 0.0, 'rand_car_64': 174.0, 'rand_car_65': 175.0, 'rand_car_67': 0.0, 'rand_car_68': 0.0, 'rand_car_70': 0.0, 'rand_car_71': 175.0, 'rand_car_73': 0.0, 'rand_car_74': 172.0, 'rand_car_75': 156.0, 'rand_car_77': 162.0, 'rand_car_79': 169.0, 'rand_car_80': 0.0, 'rand_car_81': 0.0, 'rand_car_82': 173.0, 'rand_car_83': 0.0, 'rand_car_85': 0.0, 'rand_car_84': 168.0, 'rand_car_87': 0.0, 'rand_car_88': 167.0, 'rand_car_89': 0.0, 'rand_car_92': 0.0, 'rand_car_93': 166.0, 'rand_car_94': 161.0, 'rand_car_95': 155.0, 'rand_car_96': 154.0, 'rand_car_97': 163.0, 'rand_car_99': 172.0, 'rand_car_62': 141.0, 'rand_car_66': 166.0}, 'total_congestion_avg': 32.75406504065041, 'total_speed_avg': 1.038647388191379, 'emissions': 2761.427976879855, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.2600000e+00, 6.4454999e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.0000000e-01, 1.0000000e-01,
#        1.7050000e+00, 1.0059211e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.7400002e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        7.1499997e-01, 1.7597015e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1890000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2370000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        8.1500000e-01, 1.1000114e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0130000e+00, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 300.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 299.0, 'rand_car_5': 300.0, 'rand_car_6': 0.0, 'rand_car_7': 300.0, 'rand_car_8': 300.0, 'rand_car_9': 289.0, 'rand_car_10': 0.0, 'rand_car_11': 324.0, 'rand_car_12': 0.0, 'rand_car_13': 0.0, 'rand_car_14': 0.0, 'rand_car_15': 0.0, 'rand_car_16': 279.0, 'rand_car_17': 306.0, 'rand_car_18': 300.0, 'rand_car_19': 0.0, 'rand_car_20': 0.0, 'rand_car_21': 0.0, 'rand_car_22': 255.0, 'rand_car_23': 0.0, 'rand_car_24': 265.0, 'rand_car_25': 264.0, 'rand_car_26': 0.0, 'rand_car_27': 0.0, 'rand_car_29': 300.0, 'rand_car_30': 252.0, 'rand_car_28': 256.0, 'rand_car_31': 250.0, 'rand_car_32': 242.0, 'rand_car_33': 283.0, 'rand_car_34': 288.0, 'rand_car_35': 246.0, 'rand_car_36': 249.0, 'rand_car_37': 233.0, 'rand_car_38': 300.0, 'rand_car_39': 233.0, 'rand_car_40': 270.0, 'rand_car_41': 280.0, 'rand_car_42': 234.0, 'rand_car_43': 278.0, 'rand_car_44': 269.0, 'rand_car_45': 0.0, 'rand_car_46': 268.0, 'rand_car_47': 226.0, 'rand_car_49': 223.0, 'rand_car_50': 278.0, 'rand_car_51': 228.0, 'rand_car_52': 0.0, 'rand_car_53': 0.0, 'rand_car_54': 0.0, 'rand_car_55': 220.0, 'rand_car_57': 212.0, 'rand_car_58': 260.0, 'rand_car_59': 0.0, 'rand_car_60': 215.0, 'rand_car_61': 0.0, 'rand_car_63': 0.0, 'rand_car_65': 2.0, 'rand_car_66': 207.0, 'rand_car_67': 208.0, 'rand_car_69': 196.0, 'rand_car_70': 196.0, 'rand_car_71': 199.0, 'rand_car_73': 187.0, 'rand_car_74': 191.0, 'rand_car_75': 190.0, 'rand_car_76': 0.0, 'rand_car_77': 180.0, 'rand_car_78': 0.0, 'rand_car_79': 178.0, 'rand_car_80': 300.0, 'rand_car_81': 0.0, 'rand_car_82': 0.0, 'rand_car_84': 292.0, 'rand_car_85': 0.0, 'rand_car_87': 290.0, 'rand_car_88': 0.0, 'rand_car_89': 288.0, 'rand_car_91': 0.0, 'rand_car_92': 0.0, 'rand_car_94': 155.0, 'rand_car_95': 3.0, 'rand_car_97': 0.0, 'rand_car_99': 165.0, 'rand_car_48': 137.0, 'rand_car_56': 135.0, 'rand_car_62': 134.0, 'rand_car_64': 134.0, 'rand_car_68': 133.0, 'rand_car_72': 133.0}, 'total_congestion_avg': 33.58943089430894, 'total_speed_avg': 1.006251569767401, 'emissions': 2558.617325205591, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        3.8999999e-01, 1.3750399e-16, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 9.0000004e-02, 9.0000004e-02,
#        1.5210000e+00, 1.0362322e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.8599999e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        8.9200002e-01, 2.9328357e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0000000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 9.9999998e-03, 9.9999998e-03,
#        1.6800000e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.3130000e+00, 1.5628711e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1900001e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_3': 300.0, 'rand_car_4': 298.0, 'rand_car_2': 0.0, 'rand_car_5': 300.0, 'rand_car_6': 0.0, 'rand_car_7': 0.0, 'rand_car_8': 0.0, 'rand_car_9': 0.0, 'rand_car_10': 300.0, 'rand_car_11': 300.0, 'rand_car_12': 300.0, 'rand_car_13': 295.0, 'rand_car_14': 287.0, 'rand_car_15': 264.0, 'rand_car_16': 300.0, 'rand_car_17': 300.0, 'rand_car_18': 258.0, 'rand_car_19': 262.0, 'rand_car_20': 277.0, 'rand_car_21': 0.0, 'rand_car_22': 260.0, 'rand_car_23': 294.0, 'rand_car_24': 259.0, 'rand_car_25': 253.0, 'rand_car_26': 0.0, 'rand_car_27': 266.0, 'rand_car_28': 261.0, 'rand_car_29': 260.0, 'rand_car_30': 0.0, 'rand_car_31': 259.0, 'rand_car_32': 0.0, 'rand_car_33': 240.0, 'rand_car_34': 249.0, 'rand_car_35': 0.0, 'rand_car_36': 0.0, 'rand_car_37': 249.0, 'rand_car_38': 0.0, 'rand_car_39': 0.0, 'rand_car_40': 217.0, 'rand_car_41': 216.0, 'rand_car_42': 207.0, 'rand_car_43': 230.0, 'rand_car_44': 236.0, 'rand_car_45': 223.0, 'rand_car_46': 209.0, 'rand_car_47': 232.0, 'rand_car_48': 208.0, 'rand_car_49': 220.0, 'rand_car_50': 234.0, 'rand_car_51': 0.0, 'rand_car_52': 228.0, 'rand_car_53': 214.0, 'rand_car_54': 0.0, 'rand_car_55': 194.0, 'rand_car_56': 370.0, 'rand_car_57': 0.0, 'rand_car_58': 215.0, 'rand_car_59': 0.0, 'rand_car_60': 198.0, 'rand_car_61': 202.0, 'rand_car_64': 0.0, 'rand_car_65': 176.0, 'rand_car_66': 184.0, 'rand_car_67': 0.0, 'rand_car_68': 0.0, 'rand_car_69': 195.0, 'rand_car_72': 0.0, 'rand_car_73': 176.0, 'rand_car_74': 163.0, 'rand_car_75': 181.0, 'rand_car_76': 162.0, 'rand_car_78': 0.0, 'rand_car_77': 0.0, 'rand_car_80': 0.0, 'rand_car_81': 0.0, 'rand_car_83': 164.0, 'rand_car_84': 300.0, 'rand_car_82': 161.0, 'rand_car_85': 0.0, 'rand_car_86': 0.0, 'rand_car_88': 163.0, 'rand_car_89': 160.0, 'rand_car_87': 0.0, 'rand_car_91': 161.0, 'rand_car_90': 0.0, 'rand_car_93': 0.0, 'rand_car_94': 153.0, 'rand_car_95': 0.0, 'rand_car_96': 154.0, 'rand_car_97': 152.0, 'rand_car_98': 0.0, 'rand_car_62': 162.0, 'rand_car_63': 161.0}, 'total_congestion_avg': 32.0589430894309, 'total_speed_avg': 1.1116155684779194, 'emissions': 2606.6330214876134, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.8100001e-01, 1.1458667e-16, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.9999998e-02, 7.9999998e-02,
#        1.1240000e+00, 1.1657613e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.4410000e+00, 2.5138593e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.6300000e-01, 2.9328357e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1480000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        7.8899997e-01, 1.8333524e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.2699999e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1740000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 300.0, 'rand_car_3': 300.0, 'rand_car_2': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 0.0, 'rand_car_6': 293.0, 'rand_car_7': 300.0, 'rand_car_8': 0.0, 'rand_car_9': 0.0, 'rand_car_10': 300.0, 'rand_car_11': 298.0, 'rand_car_12': 0.0, 'rand_car_13': 0.0, 'rand_car_14': 300.0, 'rand_car_15': 0.0, 'rand_car_16': 259.0, 'rand_car_17': 0.0, 'rand_car_18': 0.0, 'rand_car_19': 273.0, 'rand_car_20': 279.0, 'rand_car_21': 0.0, 'rand_car_22': 300.0, 'rand_car_23': 298.0, 'rand_car_24': 300.0, 'rand_car_26': 244.0, 'rand_car_25': 286.0, 'rand_car_27': 270.0, 'rand_car_28': 257.0, 'rand_car_29': 257.0, 'rand_car_30': 239.0, 'rand_car_31': 237.0, 'rand_car_33': 0.0, 'rand_car_32': 235.0, 'rand_car_34': 277.0, 'rand_car_35': 0.0, 'rand_car_36': 0.0, 'rand_car_37': 257.0, 'rand_car_38': 243.0, 'rand_car_39': 220.0, 'rand_car_40': 0.0, 'rand_car_41': 216.0, 'rand_car_42': 264.0, 'rand_car_43': 210.0, 'rand_car_44': 0.0, 'rand_car_45': 0.0, 'rand_car_46': 239.0, 'rand_car_47': 239.0, 'rand_car_48': 238.0, 'rand_car_49': 203.0, 'rand_car_50': 0.0, 'rand_car_51': 0.0, 'rand_car_52': 218.0, 'rand_car_53': 238.0, 'rand_car_54': 194.0, 'rand_car_55': 0.0, 'rand_car_56': 193.0, 'rand_car_57': 0.0, 'rand_car_58': 0.0, 'rand_car_59': 0.0, 'rand_car_60': 198.0, 'rand_car_61': 179.0, 'rand_car_62': 0.0, 'rand_car_63': 176.0, 'rand_car_64': 204.0, 'rand_car_65': 175.0, 'rand_car_66': 178.0, 'rand_car_67': 174.0, 'rand_car_68': 177.0, 'rand_car_69': 209.0, 'rand_car_70': 0.0, 'rand_car_72': 171.0, 'rand_car_73': 209.0, 'rand_car_77': 0.0, 'rand_car_78': 167.0, 'rand_car_79': 197.0, 'rand_car_80': 0.0, 'rand_car_81': 166.0, 'rand_car_82': 0.0, 'rand_car_83': 0.0, 'rand_car_84': 155.0, 'rand_car_85': 196.0, 'rand_car_86': 0.0, 'rand_car_87': 170.0, 'rand_car_88': 157.0, 'rand_car_91': 0.0, 'rand_car_92': 169.0, 'rand_car_93': 299.0, 'rand_car_95': 150.0, 'rand_car_94': 0.0, 'rand_car_97': 176.0, 'rand_car_98': 176.0, 'rand_car_99': 180.0, 'rand_car_71': 173.0, 'rand_car_74': 171.0, 'rand_car_75': 175.0}, 'total_congestion_avg': 31.621951219512194, 'total_speed_avg': 1.0840427156971015, 'emissions': 2607.924544297824, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        6.4499998e-01, 8.5940003e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 9.9999998e-03, 9.9999998e-03,
#        1.8000001e-01, 2.8643229e-16, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.2000000e-01, 1.2000000e-01,
#        2.2460001e+00, 8.5496098e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        8.8400000e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        5.8999997e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2520000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        6.9900000e-01, 1.8333524e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.0760000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        8.9099997e-01, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 300.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 0.0, 'rand_car_6': 300.0, 'rand_car_7': 300.0, 'rand_car_8': 300.0, 'rand_car_9': 282.0, 'rand_car_10': 0.0, 'rand_car_11': 0.0, 'rand_car_12': 264.0, 'rand_car_13': 281.0, 'rand_car_14': 276.0, 'rand_car_15': 271.0, 'rand_car_16': 0.0, 'rand_car_17': 231.0, 'rand_car_18': 300.0, 'rand_car_19': 259.0, 'rand_car_20': 257.0, 'rand_car_21': 259.0, 'rand_car_22': 242.0, 'rand_car_23': 239.0, 'rand_car_24': 0.0, 'rand_car_25': 237.0, 'rand_car_26': 245.0, 'rand_car_27': 243.0, 'rand_car_28': 225.0, 'rand_car_29': 0.0, 'rand_car_30': 0.0, 'rand_car_31': 0.0, 'rand_car_32': 0.0, 'rand_car_33': 0.0, 'rand_car_34': 263.0, 'rand_car_35': 226.0, 'rand_car_36': 230.0, 'rand_car_37': 0.0, 'rand_car_38': 221.0, 'rand_car_39': 0.0, 'rand_car_40': 243.0, 'rand_car_41': 213.0, 'rand_car_42': 0.0, 'rand_car_43': 206.0, 'rand_car_44': 198.0, 'rand_car_45': 0.0, 'rand_car_46': 204.0, 'rand_car_47': 0.0, 'rand_car_48': 194.0, 'rand_car_49': 194.0, 'rand_car_50': 223.0, 'rand_car_51': 190.0, 'rand_car_52': 193.0, 'rand_car_53': 221.0, 'rand_car_54': 165.0, 'rand_car_55': 173.0, 'rand_car_56': 167.0, 'rand_car_57': 186.0, 'rand_car_58': 162.0, 'rand_car_59': 0.0, 'rand_car_60': 172.0, 'rand_car_61': 161.0, 'rand_car_62': 0.0, 'rand_car_63': 162.0, 'rand_car_64': 176.0, 'rand_car_65': 164.0, 'rand_car_66': 0.0, 'rand_car_67': 173.0, 'rand_car_68': 0.0, 'rand_car_69': 0.0, 'rand_car_70': 0.0, 'rand_car_72': 171.0, 'rand_car_71': 0.0, 'rand_car_73': 0.0, 'rand_car_74': 176.0, 'rand_car_75': 175.0, 'rand_car_76': 161.0, 'rand_car_78': 161.0, 'rand_car_79': 161.0, 'rand_car_80': 170.0, 'rand_car_81': 0.0, 'rand_car_82': 0.0, 'rand_car_85': 0.0, 'rand_car_86': 0.0, 'rand_car_92': 160.0, 'rand_car_94': 169.0, 'rand_car_95': 269.0, 'rand_car_97': 0.0, 'rand_car_99': 145.0, 'rand_car_77': 174.0}, 'total_congestion_avg': 33.8109756097561, 'total_speed_avg': 1.133857037902173, 'emissions': 2625.9545157728285, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        9.7500002e-01, 8.5940003e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.2000000e-01, 1.2000000e-01,
#        1.8180000e+00, 1.0936545e-16, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        5.1800001e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.6200000e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2390000e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1180000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        8.1500000e-01, 1.1000114e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2980000e+00, 1.5714448e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# [{'vehicle_wait_log': {'rand_car_0': 0.0, 'rand_car_1': 0.0, 'rand_car_2': 300.0, 'rand_car_3': 300.0, 'rand_car_4': 300.0, 'rand_car_5': 0.0, 'rand_car_6': 300.0, 'rand_car_7': 300.0, 'rand_car_8': 299.0, 'rand_car_9': 0.0, 'rand_car_10': 296.0, 'rand_car_11': 290.0, 'rand_car_12': 0.0, 'rand_car_13': 271.0, 'rand_car_14': 0.0, 'rand_car_15': 271.0, 'rand_car_16': 0.0, 'rand_car_17': 256.0, 'rand_car_18': 0.0, 'rand_car_19': 300.0, 'rand_car_20': 300.0, 'rand_car_21': 0.0, 'rand_car_22': 254.0, 'rand_car_23': 254.0, 'rand_car_24': 246.0, 'rand_car_25': 0.0, 'rand_car_26': 298.0, 'rand_car_27': 236.0, 'rand_car_28': 244.0, 'rand_car_29': 292.0, 'rand_car_31': 237.0, 'rand_car_30': 285.0, 'rand_car_32': 230.0, 'rand_car_33': 300.0, 'rand_car_34': 0.0, 'rand_car_35': 299.0, 'rand_car_36': 0.0, 'rand_car_37': 270.0, 'rand_car_38': 224.0, 'rand_car_39': 0.0, 'rand_car_40': 217.0, 'rand_car_41': 0.0, 'rand_car_42': 0.0, 'rand_car_44': 281.0, 'rand_car_43': 0.0, 'rand_car_45': 207.0, 'rand_car_46': 213.0, 'rand_car_47': 212.0, 'rand_car_48': 0.0, 'rand_car_49': 260.0, 'rand_car_50': 279.0, 'rand_car_51': 258.0, 'rand_car_52': 260.0, 'rand_car_53': 276.0, 'rand_car_54': 251.0, 'rand_car_55': 0.0, 'rand_car_56': 193.0, 'rand_car_57': 0.0, 'rand_car_58': 189.0, 'rand_car_59': 187.0, 'rand_car_60': 243.0, 'rand_car_61': 239.0, 'rand_car_62': 243.0, 'rand_car_63': 226.0, 'rand_car_64': 0.0, 'rand_car_65': 249.0, 'rand_car_66': 233.0, 'rand_car_67': 0.0, 'rand_car_68': 0.0, 'rand_car_69': 0.0, 'rand_car_70': 172.0, 'rand_car_71': 167.0, 'rand_car_72': 0.0, 'rand_car_73': 216.0, 'rand_car_74': 215.0, 'rand_car_76': 212.0, 'rand_car_77': 196.0, 'rand_car_78': 0.0, 'rand_car_81': 0.0, 'rand_car_83': 0.0, 'rand_car_85': 168.0, 'rand_car_87': 196.0, 'rand_car_89': 166.0, 'rand_car_90': 0.0, 'rand_car_92': 0.0, 'rand_car_94': 165.0, 'rand_car_95': 179.0, 'rand_car_96': 165.0, 'rand_car_97': 0.0, 'rand_car_98': 163.0, 'rand_car_75': 171.0}, 'total_congestion_avg': 33.6869918699187, 'total_speed_avg': 1.206726517293615, 'emissions': 2579.0832724985717, 'TimeLimit.truncated': False, 'terminal_observation': array([0.0000000e+00, 5.0000000e-01, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.0000000e-01, 1.0000000e-01,
#        9.6499997e-01, 6.0362506e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 1.1000000e-01, 1.1000000e-01,
#        1.2100000e+00, 9.1447371e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 3.9999999e-02, 3.9999999e-02,
#        6.9000000e-01, 0.0000000e+00, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.9999999e-02, 2.9999999e-02,
#        5.2200001e-01, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.2180001e+00, 2.5138593e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00, 7.0000000e-02, 7.0000000e-02,
#        1.1740000e+00, 1.5714448e-17, 1.0000000e+00, 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 5.0000001e-02, 5.0000001e-02,
#        4.7000000e-01, 1.1000114e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 0.0000000e+00, 5.9999999e-02, 5.9999999e-02,
#        1.0230000e+00, 1.8333524e-17, 1.0000000e+00, 0.0000000e+00,
#        1.0000000e+00, 1.0000000e+00], dtype=float32)}]
# Mean Score over 15 episodes: -108130.0078125
# Mean wait time over 15 episodes: 155.39312516808522

# %%
import numpy as np
import matplotlib.pyplot as plt

spawn_rates = np.arange(0.05, 0.85, 0.2)  # Adjust range as needed

# Initialize logs
mean_wait_times_rl = []
mean_emissions_rl = []
mean_wait_times_random = []
mean_emissions_random = []

num_test_episodes = 15  # Keep both cases consistent

for spawn_rate in spawn_rates:
    print("Beginning spawn rate =", spawn_rate)
    # ============================== RL Agent ====================================
    env_rl = SumoEnv(use_gui=False, use_random=True, use_actions=True, spawn_rate=spawn_rate)
    env_rl.step(0)
    env_rl = DummyVecEnv([lambda: env_rl])

    all_wait_times_rl = []  # Collect mean wait time for each episode
    all_emissions_rl = []   # Collect emissions for each episode

    for episode in range(num_test_episodes):
        obs = env_rl.reset()
        done = False
        info = {}

        while not done:
            action, _states = loaded_model.predict(obs, deterministic=True)
            obs, reward, done, info = env_rl.step(action)

        # Collect RL agent data
        if "emissions" in info[0]:
            all_emissions_rl.append(info[0]["emissions"])
        if "vehicle_wait_log" in info[0]:
            wait_times = list(info[0]["vehicle_wait_log"].values())
            episode_mean_wait = np.mean(wait_times) if wait_times else 0  # Calculate mean for this episode
            all_wait_times_rl.append(episode_mean_wait)  # Store mean for this episode

    traci.close()

    print(all_wait_times_rl)
    
    # Store RL results
    mean_wait_time_rl = np.mean(all_wait_times_rl)  # Mean of episode means
    mean_emission_rl = np.mean(all_emissions_rl) if all_emissions_rl else 0

    print("RL: spawn_rate=", spawn_rate, "wait time mean=", mean_wait_time_rl)
    print("Wait log length RL:", len(all_wait_times_rl))
    mean_wait_times_rl.append(mean_wait_time_rl)
    mean_emissions_rl.append(mean_emission_rl)

    # ============================== Random Actions ====================================
    env_random = SumoEnv(use_gui=False, use_random=True, use_actions=False, spawn_rate=spawn_rate)

    all_wait_times_random = []  # Collect mean wait time for each episode
    all_emissions_random = []   # Collect emissions for each episode

    for episode in range(num_test_episodes):
        done = False
        info = {}

        while not done:
            action = env_random.action_space.sample()  # Random actions
            state, reward, done, truncated, info = env_random.step(action)

        # Collect Random actions data
        if "emissions" in info:
            all_emissions_random.append(info["emissions"])
        if "vehicle_wait_log" in info:
            wait_times = list(info["vehicle_wait_log"].values())
            episode_mean_wait = np.mean(wait_times) if wait_times else 0  # Calculate mean for this episode
            all_wait_times_random.append(episode_mean_wait)  # Store mean for this episode

    traci.close()

    # Store Random results
    mean_wait_time_random = np.mean(all_wait_times_random)  # Mean of episode means
    mean_emission_random = np.mean(all_emissions_random) if all_emissions_random else 0

    print("Random actions: spawn_rate=", spawn_rate, "wait time mean=", mean_wait_time_random)
    print("Random actions wait log length: ", len(all_wait_times_random))
    mean_wait_times_random.append(mean_wait_time_random)
    mean_emissions_random.append(mean_emission_random)

# ============================== Plot Results ====================================

# Define traffic density boundaries
low_traffic_end = 0.3
high_traffic_start = 0.6

# Colors for different traffic densities
low_color = "lightblue"
medium_color = "lightgreen"
high_color = "lightcoral"

# ========================= Mean Wait Time Plot =========================
plt.figure(figsize=(8, 5))

plt.axvspan(min(spawn_rates), low_traffic_end, color=low_color, alpha=0.2)
plt.axvspan(low_traffic_end, high_traffic_start, color=medium_color, alpha=0.2)
plt.axvspan(high_traffic_start, max(spawn_rates), color=high_color, alpha=0.2)


plt.plot(spawn_rates, mean_wait_times_rl, marker="o", color="red", label="RL Agent")
plt.plot(spawn_rates, mean_wait_times_random, marker="s", color="blue", linestyle="dashed", label="Traditional System")

plt.xlabel("Vehicle Spawn Rate")
plt.ylabel("Mean Wait Time (s)")
plt.title("Effect of Traffic Density on Mean Wait Time")
plt.grid(True)
plt.legend()

# Add text labels for traffic regions
#plt.text(0.05, max(mean_wait_times_rl) * 0.9, "Low Traffic", fontsize=12, color="black")
#plt.text(0.35, max(mean_wait_times_rl) * 0.9, "Medium Traffic", fontsize=12, color="black")
#plt.text(0.65, max(mean_wait_times_rl) * 0.9, "High Traffic", fontsize=12, color="black")

plt.savefig("mean_wait_time_plot_final.png")
plt.show()

# ========================= Mean Emissions Plot =========================
plt.figure(figsize=(8, 5))

plt.axvspan(min(spawn_rates), low_traffic_end, color=low_color, alpha=0.2)
plt.axvspan(low_traffic_end, high_traffic_start, color=medium_color, alpha=0.2)
plt.axvspan(high_traffic_start, max(spawn_rates), color=high_color, alpha=0.2)


plt.plot(spawn_rates, mean_emissions_rl, marker="o", color="red", label="RL Agent")
plt.plot(spawn_rates, mean_emissions_random, marker="s", color="blue", linestyle="dashed", label="Traditional System")

plt.xlabel("Vehicle Spawn Rate")
plt.ylabel("Mean Emissions (mg)")
plt.title("Effect of Traffic Density on Emissions")
plt.grid(True)
plt.legend()

plt.savefig("mean_emissions_plot_final.png")
plt.show()
