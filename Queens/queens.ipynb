# %% [markdown]
# # 0. Install Dependencies

# %%
# !pip install tensorflow
# !pip install keras
# !pip install gym
# !pip install gymnasium
# !pip install keras-rl2
# !pip install stable-baselines3
# !pip install traci
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow
# Requirement already satisfied: keras in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (3.8.0)
# Requirement already satisfied: absl-py in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (2.2.1)
# Requirement already satisfied: rich in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: gym in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gym) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gym) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: gymnasium in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from gymnasium) (0.0.4)
# Collecting keras-rl2
#   Using cached keras_rl2-1.0.5-py3-none-any.whl.metadata (304 bytes)
# INFO: pip is looking at multiple versions of keras-rl2 to determine which version is compatible with other requirements. This could take a while.
#   Using cached keras_rl2-1.0.4-py3-none-any.whl.metadata (353 bytes)
#   Using cached keras-rl2-1.0.3.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Using cached keras-rl2-1.0.2.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Using cached keras-rl2-1.0.1.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Using cached keras_rl2-1.0.0-py3-none-any.whl.metadata (342 bytes)
#
# The conflict is caused by:
#     keras-rl2 1.0.5 depends on tensorflow
#     keras-rl2 1.0.4 depends on tensorflow>=2.1.0
#     keras-rl2 1.0.3 depends on tensorflow==2.0.0-beta1
#     keras-rl2 1.0.2 depends on tensorflow==2.0.0-beta0
#     keras-rl2 1.0.1 depends on tf-nightly-2.0-preview
#     keras-rl2 1.0.0 depends on tf-nightly-2.0-preview
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
# ERROR: Cannot install keras-rl2==1.0.0, keras-rl2==1.0.1, keras-rl2==1.0.2, keras-rl2==1.0.3, keras-rl2==1.0.4 and keras-rl2==1.0.5 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Collecting stable-baselines3
#   Using cached stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from stable-baselines3) (1.0.0)
# Collecting numpy<2.0,>=1.20 (from stable-baselines3)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\li3018\TrafficLightRL\.venv\Scripts\python.exe C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48\vendored-meson\meson\meson.py setup C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48 C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48\.mesonpy-_z65gny0 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48\.mesonpy-_z65gny0\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48
#       Build dir: C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48\.mesonpy-_z65gny0
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\li3018\AppData\Local\Temp\pip-install-i9n6n3al\numpy_e94a03abda954a61941c4824d0bc9c48\.mesonpy-_z65gny0\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: traci in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (1.21.0)
# Requirement already satisfied: sumolib>=1.21.0 in c:\users\li3018\trafficlightrl\.venv\lib\site-packages (from traci) (1.21.0)

# %% [markdown]
# # 1. Build Environment with OpenAI Gymnasium

# %%
# import libraries
import numpy as np
import random
import gymnasium
import traci
import sumolib
import time

# %% [markdown]
# In the following cell we define our SumoEnv which acts as a structure that Stable Baselines3 is able to easily understand and interact with!
#
# Note that our SumoEnv Class implements the parent Class, gymnasium.Env
#
# 4 MANDITORY functions of any gymnasium.Env are init, step, render, and reset
#
# Do **not** change the input, or return parameters in any of these, as Stable Baselines3 expects a strict format!
#
# We can implement additional functions within this class, such as the arbitrary "perform_action()" function that I suggest below. This will help ensure modularity of our program.

# %%
class SumoEnv(gymnasium.Env):
  def __init__(self, use_gui=False, use_random=False, use_actions=True):
    super().__init__() # Initializes the parent class

    # Check if TraCI is already loaded; if so, close it
    if traci.isLoaded():
      traci.close()

    # Define the Discrete action space with gymnasium.spaces.Discrete(n)
    # choices are up & down = green, or l & r = green
    self.action_space = gymnasium.spaces.Discrete(2)

    # Define the Box observation space with gymnasium.spaces.Box()
    # Note the structure of the Box parameters requires NumPy arrays!
    
    max_cars = 20 # CHANGE FOR ACTUAL MAX. NUMBER OF CARS
    self.max_cars = max_cars
    
    self.car_spawn_rate = 0.3 # cars spawn at 30% chance

    # np array structure: [traffic_light_phase][positions][speeds], dtype=np.float32
    self.observation_space = gymnasium.spaces.Box(
      low=np.array([0] + [-np.inf] * (2 * max_cars) + [0] * max_cars),
      high=np.array([3] + [np.inf] * (2 * max_cars) + [np.inf] * max_cars),
      dtype=np.float32
    )
    
    # Upon each render of the SumoEnv Class, we should start the simulation
    # Implement the sumo_binary, sumo_config, and traci.start from test_demo.py
    self.use_gui = use_gui
    if use_gui:
      sumo_binary = sumolib.checkBinary('sumo-gui')
    else:
      sumo_binary = sumolib.checkBinary('sumo')

    # use the proper .sumocfg file depending on if want predefined or random cars
    self.use_random = use_random
    if use_random:
      sumo_config = "./demo_net/random.sumocfg"
    else:
      sumo_config = "./demo_net/demo.sumocfg"
    
    # used to track number of deployed cars
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # store these variables for use later
    self.sumo_binary = sumo_binary
    self.sumo_config = sumo_config

    # Start the simulation
    self.started = False

    # Track cumulative metrics
    self.vehicle_wait_log = {}
    self.total_congestion_log = []
    self.total_speed_log = []

    # use actions argument: False = use the timer based system instead (for comparing between agent and real-life)
    self.use_actions = use_actions

    # Define consistent pause time for sumo-gui visualization
    self.pause_time = 0.1

  def step(self, action):
    # On first step, start the traci sim
    if not self.started:
      traci.start([self.sumo_binary, "--start", "-c", self.sumo_config])
      self.started = True
      traffic_light_id = traci.trafficlight.getIDList()[0]
      traci.trafficlight.setPhase(traffic_light_id, 0)
      if self.use_actions:
        traci.trafficlight.setPhaseDuration(traffic_light_id, 99999)  # Hold this phase indefinitely
    
    # Perform the action
    if self.use_actions:
      self.perform_action(action)
    
    # Spawn in a car if suits the spawn rate on step
    if self.use_random:
      if (random.random() < self.car_spawn_rate) and (self.deployed_counter < self.max_cars):
        self.spawn_random_car(self.deployed_counter)
        self.deployed_counter += 1
  

    # Advance the simulation by one step
    traci.simulationStep()
    if self.use_gui: # pause in between steps to slow down if in 'simulation mode'
      time.sleep(self.pause_time) 
    print("Step: " + str(traci.simulation.getTime()))
    # Get the new state
    observation = self.get_state()

    # Calculate the reward
    reward = self.calculate_reward()

    # Determine if simulation is done
    done = self.is_done()

    # Set placeholder for info -> returns the tracked cumulative metrics IF done
    info = {
      "vehicle_wait_log": self.vehicle_wait_log if done else None,
      "total_congestion_avg": (sum(self.total_congestion_log) / len(self.total_congestion_log)) if done and self.total_congestion_log else None,
      "total_speed_avg": (sum(self.total_speed_log) / len(self.total_speed_log)) if done and self.total_speed_log else None
    }

    # Set placeholder for truncated
    truncated = False

    # set 'observation' to a numpy array
    observation = np.array(observation, dtype=np.float32)

    # Return step information (MUST follow this order of variables!!!)
    return observation, reward, done, truncated, info

  def render(self):
    # render needs to exist in the Gymnasium env, as it is an essential aspect
    # however we might not need to put anything inside it, hence 'pass'
    # this depends on if the command -> traci.simulationStep() exists somewhere else in the Class
    pass

  def reset(self, seed=None, options=None):

    # resets the gymnasium.Env parent class
    super().reset(seed=seed)

    # close the simulation (reset)
    if not self.use_gui: # traci.load() doesn't work for sumo-gui - i.e. can only run once
      traci.load(["-c", self.sumo_config])

    # reset counter variables
    if self.use_random:
      self.deployed_counter = 0
    else:
      self.deployed_counter = 1

    # convert 'observation' to a NumPy array
    observation = np.array(self.get_state(), dtype=np.float32)

    # return 'observation' and 'info' --> MUST be in this form
    return observation, {}

  def get_state(self):
    # Get the traffic light phase
    traffic_light_ids = traci.trafficlight.getIDList()
    traffic_light_phase = traci.trafficlight.getPhase(traffic_light_ids[0]) # only 1 in this network

    # Get vehicle IDs and limit to max_cars
    vehicle_ids = traci.vehicle.getIDList()

    # Collect positions and speeds, padding if fewer than max_cars
    positions = []
    speeds = []
    for v_id in vehicle_ids:
      position = traci.vehicle.getPosition(v_id)  # Returns (x, y) tuple
      speed = traci.vehicle.getSpeed(v_id)
      positions.extend(position)  # Add x, y to positions list
      speeds.append(speed)

    # Pad positions and speeds if there are fewer than max_cars vehicles
    if len(vehicle_ids) < self.max_cars:
      missing_cars = self.max_cars - len(vehicle_ids)
      positions.extend([0.0, 0.0] * missing_cars)
      speeds.extend([0.0] * missing_cars)

    # Create the state as a numpy array
    obs = np.array([traffic_light_phase] + positions + speeds, dtype=np.float32)
    return obs

  def perform_action(self, action, intersection_1, intersection_2):

    light_id = traci.trafficlight.getIDList()[0]
    current_phase = traci.trafficlight.getPhase(light_id)
    
    self.intersection_1 = None  
    self.intersection_2 = None
    # """
    # Phases: 
    #   (0) E & W = green, N & S = red
    #   (1) E & W = yellow, N & S = red
    #   (2) E & W = red, N & S = green
    #   (3) E & W = red, N & S = yellow

    #   Define action 1 as switching green to E & W; thus turning N & S red
    #   Define action 2 as switching green to N & S; thus turning E & W red
     
    #   Also, no actions can be performed during yellow light!
    # """

    # if action == 0 and current_phase != 0:
    #   traci.trafficlight.setPhase(light_id, 3)  # transition to yellow
    #   traci.trafficlight.setPhaseDuration(light_id, 3)  # set yellow duration
    #   self.skip_steps(3)
    #   traci.trafficlight.setPhase(light_id, 0)  # set E-W green
    #   traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
    #   self.skip_steps(5) # ensure light is green for at least 3 seconds

    # elif action == 1 and current_phase != 2:
    #   traci.trafficlight.setPhase(light_id, 1)  # transition to yellow
    #   traci.trafficlight.setPhaseDuration(light_id, 3)
    #   self.skip_steps(3)
    #   traci.trafficlight.setPhase(light_id, 2)  # set N-S green
    #   traci.trafficlight.setPhaseDuration(light_id, 99999)  # Hold this phase indefinitely
    #   self.skip_steps(5)
    
    #first intersection
    """
    first intersection phases: 
      (0) E & W = green, N & S = red
      Duration: 38 seconds (default), min: 5s, max: 50s.
      (1) E & W = yellow and green light with no priority, N & S = red
      Duration: 3 seconds (default), 
      (2) E & W = red and green light with pr, N & S = red
      Duration: 6 seconds (default), min: 5s, max: 50s
      (3) E & W = red and left turns are yellow, N & S = red
      Duration: 3 seconds (default), 
      (4) E & W = red, N & S = green
      Duration: 37 seconds (default), min: 5s, max: 50s
      (5) E & W = red, N & S = yellow
    Duration: 3 seconds (default), 
    """
    """
    PHASE FOR SECOND INTERSECTION 
        (0)Green for E-W traffic (both straight and left turns).
        Red for N-S traffic.
        Duration: Default is 42 seconds (min: 5, max: 50).  
        (1)Yellow for E-W traffic (transition phase to stop).
        Red for N-S traffic.
        Duration: Fixed at 3 seconds.
        (2)Green for N-S traffic (both straight and left turns).
        Red for E-W traffic.
        Duration: Default is 42 seconds (min: 5, max: 50).
        (3)Yellow for N-S traffic (transition phase to stop).
        Red for E-W traffic.
        Duration: Fixed at 3 seconds.
    """
  
     # Action mapping
    if action == 0:  # Action 0: Switch green to E-W at the first intersection
      if intersection_1.current_phase not in [1, 5]:  # Ensure not in yellow phase
        transition_to_ew_green(intersection_1)

    elif action == 1:  # Action 1: Switch green to N-S at the first intersection
        if intersection_1.current_phase not in [1, 5]:  # Ensure not in yellow phase
          transition_to_ns_green(intersection_1)

    elif action == 2:  # Action 2: Switch green to E-W at the second intersection
        if intersection_2.current_phase not in [1, 3]:  # Ensure not in yellow phase
          transition_to_ew_green(intersection_2)

    elif action == 3:  # Action 3: Switch green to N-S at the second intersection
        if intersection_2.current_phase not in [1, 3]:  # Ensure not in yellow phase
            transition_to_ns_green(intersection_2)

    def transition_to_ew_green(intersection):
      """Transition to East-West Green Phase."""
      if intersection.current_phase != 0:  # If not already in E-W green
          intersection.current_phase = 1
          traci.trafficlight.set_Phase(intersection, 1)  # Yellow transition
          self.skip_steps(3)  # Wait for yellow light duration
          intersection.current_phase = 0 # transition to E-W green
          traci.trafficlight.set_Phase(intersection, 0)  # Switch to E-W green

    def transition_to_ns_green(intersection):
        """Transition to North-South Green Phase."""
        if intersection.current_phase in [0, 1, 2, 3]:  # Ensure we're not already in N-S green
            if intersection.current_phase in [0, 1]:  # For Intersection 1
                intersection.current_phase = 5  # Transition to yellow light for N-S
                traci.trafficlight.set_phase(intersection, 5)  # Set the phase to yellow
                self.skip_steps(3)  # Wait for yellow light duration
                intersection.current_phase = 4  # Transition to N-S green
                traci.trafficlight.set_phase(intersection, 4)  # Set the phase to N-S green
            elif intersection.current_phase in [2, 3]:  # For Intersection 2
                intersection.current_phase = 3  # Transition to yellow light for N-S
                traci.trafficlightset_phase(intersection, 3)  # Set the phase to yellow
                self.skip_steps(3)  # Wait for yellow light duration
                intersection.current_phase = 2  # Transition to N-S green
                traci.trafficlight.set_phase(intersection, 2)  # Set the phase to N-S green

  def phase_duration(intersection, phase): 
    intersection.current_phase = phase  # Update the intersection's current phase

    # Define phase durations based on the phase and intersection
    if intersection.id == "1":
        if phase == 0:  # E-W green, N-S red
            intersection.phase_duration = 38
        elif phase == 1:  # E-W yellow
            intersection.phase_duration = 3
        elif phase == 2:  # E-W red with green priority
            intersection.phase_duration = 6
        elif phase == 3:  # E-W red with yellow for left turns
            intersection.phase_duration = 3
        elif phase == 4:  # N-S green, E-W red
            intersection.phase_duration = 37
        elif phase == 5:  # N-S yellow
            intersection.phase_duration = 3

    elif intersection.id == "2":
        if phase == 0:  # E-W green, N-S red
            intersection.phase_duration = 42
        elif phase == 1:  # E-W yellow
            intersection.phase_duration = 3
        elif phase == 2:  # N-S green, E-W red
            intersection.phase_duration = 42
        elif phase == 3:  # N-S yellow
            intersection.phase_duration = 3


  def calculate_reward(self):
    # REWARD FUNCTION: Calculate the reward (should be negative if in a poor state i.e. high congestion)
    lane_ids = traci.lane.getIDList()
    vehicle_ids = traci.vehicle.getIDList()
    try:
      congestion = self.calculate_congestion(vehicle_ids)
      wait_time = self.calculate_avg_wait_time(lane_ids)
      stops = self.calculate_total_stops(lane_ids)
      avg_speed = self.calculate_avg_speed(vehicle_ids)# -> would be maximize so don't multiply by -1
      reward = -1*(1.5*congestion + 1.5*wait_time + stops) + 0.75*avg_speed # minimize all terms
    except:
      reward = 0

    return reward

  def skip_steps(self, x):
    for _ in range(x): 
      traci.simulationStep()
      if self.use_gui:
        time.sleep(self.pause_time)

  def is_done(self):
    max_time = 1000  # Example maximum simulation time
    return (traci.simulation.getTime() >= max_time or len(traci.vehicle.getIDList()) == 0) and self.deployed_counter != 0


  # METRICS:
  def calculate_congestion(self, vehicle_ids):
    congestion = 0
    current_time = traci.simulation.getTime()  # Get the current simulation time
    
    for vehicle_id in vehicle_ids:
      departure_time = traci.vehicle.getDeparture(vehicle_id)  # Get each vehicle's departure time
      speed = traci.vehicle.getSpeed(vehicle_id)  # Get the vehicle's current speed
      
      # Check if the vehicle is stopped and not just starting/departing
      if speed == 0 and current_time not in range(int(departure_time) - 1, int(departure_time) + 2):
          congestion += 1  # Increment congestion counter for stopped vehicles
  
    # update congestion log
    self.total_congestion_log.append(congestion)

    return congestion


  def calculate_avg_wait_time(self, lane_ids):
    wait_times = []
    
    # total wait time of cars in all lanes
    for lane_id in lane_ids:
      # total wait time of all cars in one lane
      for vehicle_id in traci.lane.getLastStepVehicleIDs(lane_id):
          wait_time = traci.vehicle.getWaitingTime(vehicle_id)

          # update the wait log
          if vehicle_id in self.vehicle_wait_log:
            self.vehicle_wait_log[vehicle_id] = max(self.vehicle_wait_log[vehicle_id], wait_time) # only want the greatest average wait time for each vehicle
          else:
            self.vehicle_wait_log[vehicle_id] = wait_time

          wait_times.append(wait_time)
  
    avg_wait_time = sum(wait_times)/len(wait_times) if wait_times else 0
    
    return avg_wait_time

  def calculate_total_stops(self, lane_ids):
    total_stops = 0
    for lane_id in lane_ids:
      stops_in_lane = traci.lane.getLastStepHaltingNumber(lane_id)
      total_stops += stops_in_lane

    return total_stops
    
  def calculate_avg_speed(self, vehicle_ids):
    total_speed = sum(traci.vehicle.getSpeed(v_id) for v_id in vehicle_ids)
    avg_speed = total_speed / len(vehicle_ids) if vehicle_ids else 0

    # update total speed log
    self.total_speed_log.append(avg_speed)

    return avg_speed

  def spawn_random_car(self, step_counter):
    """
    Spawns a random car with a unique ID and assigns it a random route.
    edge_mapping represents the available routes that any car can take; start_edge:end_edge
    """
    
    #Intersection 1
    edge_mapping = {
       "intersection 1": {
          #north 
            "-388930252#1": "28160915#2",
            "-388930252#1": "-4754858#1",
            "-388930252#1": "28160917#2",
            "-388930252#1": "388930252#1",

          # south
            "4754858#1": "28160917#2",
            "4754858#1": "28160915#2",
            "4754858#1": "388930252#1",
            "4754858#1": "-4754858#1",
          
          #east 
            "28160914#0": "28160917#2",
            "28160914#0": "-4754858#1",
            "28160914#0": "388930252#1",
            "28160914#0": "28160915#2",
          
          #west
            "4976399#0": "388930252#1",
            "4976399#0": "28160915#2",
            "4976399#0": "-4754858#1",
            "4976399#0": "28160917#2",
       },
       "intersection 2": {
          #north 
            "-4754851#1": "-28160916#2",
            "-4754851#1": "28160916#5",
            "-4754851#1": "4754851#1",

          #east
            "28160916#2": "28160916#5",
            "28160916#2": "4754851#1",
            "28160916#2": "-28160916#2",

          #west
            "-28160916#5": "4754851#1",
            "-28160916#5": "-28160916#2",
            "-28160916#5": "28160916#5",
       }
    }
    vehicle_id = f"rand_car_{step_counter}"

    edges = traci.edge.getIDList()
    start_edges = []
    for edge in edges:
        if not edge.startswith('-') and not edge.startswith(':'):
            start_edges.append(edge)
    
    start_edge = random.choice(start_edges)
    end_edge = edge_mapping[start_edge]

    route_id = f"route_{vehicle_id}"

    try:
        traci.route.add(routeID=route_id, edges=[start_edge, end_edge])

        # Add the vehicle to the simulation
        traci.vehicle.add(vehID=vehicle_id, routeID=route_id)

        print(f"Deployed random vehicle {vehicle_id} from {start_edge} to {end_edge}")

        # Set a random speed for the vehicle
        traci.vehicle.setSpeed(vehicle_id, random.uniform(5, 15))

    except traci.TraCIException as e:
        print(f"Failed to add vehicle {vehicle_id} on route from {start_edge} to {end_edge}: {e}")

# %% [markdown]
# ### Test env with random actions and SUMO (no GUI)

# %%
# the purpose of this is just to visualize our results!
env = SumoEnv(use_gui=False, use_random=True, use_actions=False) # use_gui=False sets sumo_binary to 'sumo' instead of 'sumo-gui'

episodes = 10 # note can only be run ONCE with sumo-gui!
score_log = []
wait_log = []
for episode in range(1, episodes+1):
    #state, _ = env.reset()
    done = False
    truncated = False
    score = 0
    info = {}
    while not done:
        env.render()
        action = env.action_space.sample()
        state, reward, done, truncated, info = env.step(action)
        score+=reward
    state, _ = env.reset()
    score_log.append(score)
    print(info)
    wait_times = info.get('vehicle_wait_log', {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars
    wait_log.append(episode_mean_wait)


traci.close()
mean_sample_score = np.mean(score_log)*episodes
print(f"Mean Score over {episodes} episodes: {mean_sample_score}")
print(f"Mean wait time over {episodes} episodes: {np.mean(wait_log)}")
print(f"Mean congestion over {episodes} episodes: {info.get('total_congestion_avg')}")
print(f"Mean speed over {episodes} episodes: {info.get('total_speed_avg')}")
# Out:
# c:\Users\li3018\TrafficLightRL\.venv\Lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# c:\Users\li3018\TrafficLightRL\.venv\Lib\site-packages\gymnasium\spaces\box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64326 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64331 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64336 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64341 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64345 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64350 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64357 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 64365 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52851 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52862 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52870 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52879 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52885 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52889 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52894 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52903 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52908 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52915 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52921 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52926 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52931 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52941 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52958 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52965 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52970 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52979 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52992 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 52999 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53004 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53009 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53020 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53025 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53030 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53040 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53047 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53054 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53067 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53072 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53080 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53089 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53092 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53097 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53102 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53107 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53112 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53116 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53122 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53133 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53142 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53147 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53152 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53159 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53164 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53169 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53173 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53179 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53184 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53189 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53196 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53200 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:154: UserWarning: Could not connect to TraCI server using port 53207 (TraCI server already finished). Retrying with different port.
#   warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# Cell In[4], line 16
#      14     env.render()
#      15     action = env.action_space.sample()
# ---> 16     state, reward, done, truncated, info = env.step(action)
#      17     score+=reward
#      18 state, _ = env.reset()
#
# Cell In[3], line 70, in SumoEnv.step(self, action)
#      67 def step(self, action):
#      68   # On first step, start the traci sim
#      69   if not self.started:
# ---> 70     traci.start([self.sumo_binary, "--start", "-c", self.sumo_config])
#      71     self.started = True
#      72     traffic_light_id = traci.trafficlight.getIDList()[0]
#
# File C:\Program Files (x86)\Eclipse\Sumo\tools\traci\main.py:157, in start(cmd, port, numRetries, label, verbose, traceFile, traceGetters, stdout, doSwitch)
#     154         warnings.warn(("Could not connect to TraCI server using port %s (%s)." +
#     155                        " Retrying with different port.") % (sumoPort, e))
#     156         numRetries -= 1
# --> 157 raise FatalTraCIError("Could not connect.")
#
# FatalTraCIError: Could not connect.

# %% [markdown]
# ### Test env with random actions and SUMO-GUI

# %%
# the purpose of this is just to visualize our results!
env = SumoEnv(use_gui=True, use_random=True, use_actions=False) # set use_gui arg to True

episodes = 1 # note can only be run ONCE with sumo-gui!
score_log = []
for episode in range(1, episodes+1):
    #state, _ = env.reset()
    done = False
    truncated = False
    score = 0
    while not done:
        env.render()
        action = env.action_space.sample()
        state, reward, done, truncated, info = env.step(action)
        score+=reward

    score_log.append(score)

traci.close()
mean_sample_score = np.mean(score_log)*episodes
print(f"Mean Score over {episodes} episodes: {mean_sample_score}")

# %% [markdown]
# # 2. Create Agent with Stable Baselines3

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# CREATE NEW VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# TRAIN AGENT
model = PPO("MlpPolicy", env, verbose=1)
# can change number of timesteps, however at least 10000 to make a semi-decent one
model.learn(total_timesteps=150000) # takes ~15 mins

# %% [markdown]
# ### Test agent with SUMO

# %%
# CREATE VEC ENV
env = SumoEnv(use_gui=False, use_random=True, use_actions=True)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODES
num_test_episodes = 10
all_scores = []

# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0

    while not done:
        action, _states = model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)

traci.close()
# Calculate the mean score across all test episodes
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")

# %% [markdown]
# ### Test agent with SUMO-GUI (visualize results)

# %%
# CREATE VEC ENV
env = SumoEnv(True)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODE (ONLY ONE FOR SUMO-GUI)
num_test_episodes = 1
all_scores = []

# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0

    while not done:
        action, _states = model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)
traci.close()
# Calculate the mean score across all test episodes
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")

# %% [markdown]
# # 3. Saving and loading the trained agent

# %%
# SAVE THE MODEL
model.save("ppo_model-2") # creates ppo_model.zip in current working directory

# %%
loaded_model = PPO.load("ppo_model-2")

# %% [markdown]
# ### Test the loaded agent with SUMO

# %%
# CREATE VEC ENV
env = SumoEnv(use_gui=True, use_random=True, use_actions=False)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODES
num_test_episodes = 1
all_scores = []
wait_log = []
# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0
    info = {}
    while not done:
        action, _states = loaded_model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)

    print(info)
    wait_times = info[0].get('vehicle_wait_log', {}).values()
    total_wait_time = sum(wait_times)
    num_cars = len(wait_times)
    episode_mean_wait = total_wait_time / num_cars
    wait_log.append(episode_mean_wait)

traci.close()
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")
print(f"Mean wait time over {num_test_episodes} episodes: {np.mean(wait_log)}")

# %% [markdown]
# ### Test the loaded agent with SUMO-GUI (visualize results)

# %%
# CREATE VEC ENV
env = SumoEnv(True)
env.step(0)
check_env(env)
env = DummyVecEnv([lambda: env])

# %%
# RUN TEST EPISODE (ONLY ONE FOR SUMO-GUI)
num_test_episodes = 1
all_scores = []

# Run multiple test episodes
for episode in range(num_test_episodes):
    obs = env.reset()
    done = False
    episode_score = 0

    while not done:
        action, _states = model.predict(obs, deterministic=True)  # Use deterministic actions during testing
        obs, reward, done, info = env.step(action)
        episode_score += reward

    all_scores.append(episode_score)
traci.close()
# Calculate the mean score across all test episodes
mean_score = np.mean(all_scores)
print(f"Mean Score over {num_test_episodes} episodes: {mean_score}")
